# %% [markdown]
# Started the competition as I was busy with work and life today, Saturday, June 15, 2019.
#
# Important things to note:
#
#     Baseline XGBoost model with original aggregated features is AUC: .68+
#     Adding minutes aggregation will result to +.06 points to get AUC 0.74+ on Hold-out set

# %% [markdown]
# ### Approach
#
# 1. aggregate the dataframe with original features (with second)
# 2. aggregate the dataframe with minutes (second converted to minute) and merge with original aggregated dataframe using bookingid
# 3. train models on the whole feature set with XGB and LGB
# 4. use bayesian optimization to find the optimal parameters
# 5. retrain the model using the found parameters stored in .dict file (for xgb and lgb)
# 6. predict and check results.

# %% [markdown]
# ### How to use the notebook
# Step by step:
#
# 1. instantiate the variables for labels and features
# 2. run get_all_data to get the initial dataframe
# 3. run process_all_data to get X_train, X_test, y_train, y_test
# 4. run xgb_optimize and lgb_optimize
# 5. run get_test_result to get the hold out evaluation (using X_test as your hold out data and y_test as your ground truth data.
#
# Additional steps for grab evaluator:
# 6. run get_all_data for your files for the initial dataframe
# 7. run process_all_data and set test_grab_evaluation=True to get your final process dataframe
# 8. run get_test_result to get the evaluation score of your files (using run_process_all_data output as your hold out data and your file(s) ground truth data.

# %%
import pandas as pd
import numpy as np
from modules.utils import reduce_mem_usage, interaction_features, data_aggregation_in_minutes
from modules.models import optimize_lgb, optimize_xgb, xgb_cv, lgb_cv
import glob #file handling
from itertools import combinations
import gc #garbage collector for memory usage efficiency
gc.enable()

# %%
from sklearn.metrics import roc_auc_score
from sklearn.model_selection import train_test_split, KFold, StratifiedKFold

# %%
labels = pd.read_csv(glob.glob('../labels/*.csv')[0])
features = sorted(glob.glob('../features/*.csv')) #sort from 0-9

# %%
def get_all_data(labels, features):
    labels.columns = [x.lower() for x in labels.columns]
    df = pd.DataFrame()
    for file in features:
        print(f"processing file {file}")
        new_df = pd.read_csv(file)
        new_df = reduce_mem_usage(new_df)
        df = df.append(new_df)
        del new_df
        gc.collect()
    return df

# %%
df = get_all_data(labels, features)
# Out:
# processing file ../features/part-00000-e6120af0-10c2-4248-97c4-81baf4304e5c-c000.csv
# Memory usage of dataframe is 135.41 MB
# Memory usage after optimization is: 46.16 MB
# Decreased by 65.9%
# processing file ../features/part-00001-e6120af0-10c2-4248-97c4-81baf4304e5c-c000.csv
# Memory usage of dataframe is 135.42 MB
# Memory usage after optimization is: 46.16 MB
# Decreased by 65.9%
# processing file ../features/part-00002-e6120af0-10c2-4248-97c4-81baf4304e5c-c000.csv
# Memory usage of dataframe is 135.42 MB
# Memory usage after optimization is: 46.16 MB
# Decreased by 65.9%
# processing file ../features/part-00003-e6120af0-10c2-4248-97c4-81baf4304e5c-c000.csv
# Memory usage of dataframe is 135.41 MB
# Memory usage after optimization is: 46.16 MB
# Decreased by 65.9%
# processing file ../features/part-00004-e6120af0-10c2-4248-97c4-81baf4304e5c-c000.csv
# Memory usage of dataframe is 135.42 MB
# Memory usage after optimization is: 46.16 MB
# Decreased by 65.9%
# processing file ../features/part-00005-e6120af0-10c2-4248-97c4-81baf4304e5c-c000.csv
# Memory usage of dataframe is 135.41 MB
# Memory usage after optimization is: 46.16 MB
# Decreased by 65.9%
# processing file ../features/part-00006-e6120af0-10c2-4248-97c4-81baf4304e5c-c000.csv
# Memory usage of dataframe is 135.41 MB
# Memory usage after optimization is: 46.16 MB
# Decreased by 65.9%
# processing file ../features/part-00007-e6120af0-10c2-4248-97c4-81baf4304e5c-c000.csv
# Memory usage of dataframe is 135.42 MB
# Memory usage after optimization is: 46.16 MB
# Decreased by 65.9%
# processing file ../features/part-00008-e6120af0-10c2-4248-97c4-81baf4304e5c-c000.csv
# Memory usage of dataframe is 135.42 MB
# Memory usage after optimization is: 46.16 MB
# Decreased by 65.9%
# processing file ../features/part-00009-e6120af0-10c2-4248-97c4-81baf4304e5c-c000.csv
# Memory usage of dataframe is 135.42 MB
# Memory usage after optimization is: 46.16 MB
# Decreased by 65.9%

# %%
def process_all_data(df, test_grab_evaluation=False):
    """
    This function will handle the processing of the dataframe to be model-consumable.
    Please handle the merging of the labels on your own (if you are evaluating the model(s)
    just set your processed file to the test_ param in the models module.

    Returns:
        if grab evaluation:
            final_df : final dataframe without label (for evaluation)
        my case:
            X_train, X_test, y_train, y_test : sets of processed data for training and evaluation
    """
    print("Generating dataframe and feature engineering.....")
    df.columns = [x.lower() for x in df.columns]
    df = df.merge(labels, on='bookingid', how='left')
    ids_with_duplicate_labels = df[['bookingid', 'label']].groupby(['bookingid']).agg(np.mean)
    ids_with_duplicate_labels=ids_with_duplicate_labels.loc[ids_with_duplicate_labels['label'] == 0.5]\
                .reset_index()['bookingid'].unique()
    df = df.set_index('bookingid').drop(ids_with_duplicate_labels).reset_index()
    df = df.sort_values(['bookingid', 'second'], ascending=True)

    df['total_acceleration'] = np.sqrt((df['acceleration_x'] ** 2) + \
                                       (df['acceleration_y'] ** 2) + (df['acceleration_z'] ** 2))

    #https://physics.stackexchange.com/questions/41653/how-do-i-get-the-total-acceleration-from-3-axes

    df['gyro_magnitude'] = np.sqrt((df['gyro_x'] ** 2) + \
                                       (df['gyro_y'] ** 2) + (df['gyro_z'] ** 2))

    #https://electronics.stackexchange.com/questions/92447/is-the-magnitude-of-gyro-xyz-meaningful
    print('generating interaction features....')
    for e, (x, y) in enumerate(combinations(['speed', 'accuracy', 'bearing','total_acceleration', 'gyro_magnitude'], 2)):
        df = interaction_features(df, x, y, e)

    df.drop('label',axis=1, inplace=True) #drop again after finding the duplicate labels

    final_df = df.drop('second', axis=1).groupby('bookingid')\
            .agg([np.mean, max, min, np.std, sum]) ##aggregation for original df

    final_df.columns = ['_orig_'.join(col).strip() for col in final_df.columns.values]
    final_df = final_df.reset_index()
    minute_list = [1,5,10,15,20,25,30,60]
    print(f"generating feature engineering using minutes in {minute_list} ....")
    for m in minute_list:
        to_append_df = data_aggregation_in_minutes(df, minute=m)
        to_append_df = to_append_df.drop('minute', axis=1).groupby('bookingid').agg(np.mean).reset_index()
        final_df = final_df.merge(to_append_df, on='bookingid', how='left')
        del to_append_df
        gc.collect()
    del df
    gc.collect()
    print('Done!')
    if test_grab_evaluation:
        """
        Return the generated/processed dataframe for Grab evaluation.
        Please handle the labels of your files on your own (ground truth of your evaluation data)
        """
        return final_df
    else:
        """
        My Case.
        """
        final_df = final_df.merge(labels, on='bookingid', how='left')
        X_train, X_test, y_train, y_test = train_test_split(\
                    final_df.drop('label', axis=1), final_df.label, test_size=0.25, random_state=42)

        return X_train, X_test, y_train, y_test

# %%
X_train, X_test, y_train, y_test = process_all_data(df, test_grab_evaluation=False)
# Out:
# Generating dataframe and feature engineering.....
# generating interaction features....
# generating feature engineering using minutes in [1, 5, 10, 15, 20, 25, 30, 60] ....
# Done!

# %%
#X_train, X_test, y_train, y_test = pd.read_pickle('X_train.pkl'), \
# pd.read_pickle('X_test.pkl'),  pd.read_pickle('y_train.pkl'),  pd.read_pickle('y_test.pkl')

# %%
init_points = 10
num_iter = 20
num_params = 1
stratify=True

# %%
optimize_lgb(X_train, X_test, y_train, init_points=init_points, num_iter=num_iter,\
             num_params=num_params, stratify=stratify)
# Out:
# Bayesian optimization results will be stored in lgb_BO_res_optimization.dict after training...
# |   iter    |  target   | baggin... | baggin... | featur... |  max_bin  | min_da... | min_ga... | min_su... | num_le... | reg_alpha | reg_la... |
# -------------------------------------------------------------------------------------------------------------------------------------------------
# Training until validation scores don't improve for 500 rounds.
# [1000]	training's auc: 0.764769	valid_1's auc: 0.718392
# [2000]	training's auc: 0.783211	valid_1's auc: 0.719689
# Early stopping, best iteration is:
# [2420]	training's auc: 0.789068	valid_1's auc: 0.720201
# Fold  1 AUC : 0.720201
# Training until validation scores don't improve for 500 rounds.
# [1000]	training's auc: 0.763703	valid_1's auc: 0.726267
# [2000]	training's auc: 0.781967	valid_1's auc: 0.72731
# Early stopping, best iteration is:
# [2258]	training's auc: 0.785487	valid_1's auc: 0.727839
# Fold  2 AUC : 0.727839
# Training until validation scores don't improve for 500 rounds.
# [1000]	training's auc: 0.765412	valid_1's auc: 0.715465
# [2000]	training's auc: 0.783367	valid_1's auc: 0.716166
# Early stopping, best iteration is:
# [1760]	training's auc: 0.779821	valid_1's auc: 0.716567
# Fold  3 AUC : 0.716567
# Training until validation scores don't improve for 500 rounds.
# [1000]	training's auc: 0.765522	valid_1's auc: 0.714784
# [2000]	training's auc: 0.784194	valid_1's auc: 0.716013
# Early stopping, best iteration is:
# [1653]	training's auc: 0.778648	valid_1's auc: 0.716346
# Fold  4 AUC : 0.716346
# Training until validation scores don't improve for 500 rounds.
# Early stopping, best iteration is:
# [374]	training's auc: 0.740554	valid_1's auc: 0.7304
# Fold  5 AUC : 0.730400
# Full AUC score 0.721438
# |  1        |  0.7214   |  0.1915   |  0.6221   |  0.247    |  123.2    |  4.12e+03 |  0.2726   |  0.000145 |  33.07    |  0.9581   |  0.8759   |
# Training until validation scores don't improve for 500 rounds.
# Early stopping, best iteration is:
# [257]	training's auc: 0.792	valid_1's auc: 0.730401
# Fold  1 AUC : 0.730404
# Training until validation scores don't improve for 500 rounds.
# Early stopping, best iteration is:
# [287]	training's auc: 0.79749	valid_1's auc: 0.72818
# Fold  2 AUC : 0.728180
# Training until validation scores don't improve for 500 rounds.
# Early stopping, best iteration is:
# [149]	training's auc: 0.773186	valid_1's auc: 0.728839
# Fold  3 AUC : 0.728839
# Training until validation scores don't improve for 500 rounds.
# Early stopping, best iteration is:
# [429]	training's auc: 0.817938	valid_1's auc: 0.727036
# Fold  4 AUC : 0.727036
# Training until validation scores don't improve for 500 rounds.
# Early stopping, best iteration is:
# [125]	training's auc: 0.763327	valid_1's auc: 0.738858
# Fold  5 AUC : 0.738858
# Full AUC score 0.729893
# |  2        |  0.7299   |  0.3578   |  0.501    |  0.3576   |  114.1    |  2.481e+0 |  0.5612   |  0.000256 |  5.482    |  0.7728   |  0.8826   |
# Training until validation scores don't improve for 500 rounds.
# [1000]	training's auc: 0.756406	valid_1's auc: 0.710822
# [2000]	training's auc: 0.772302	valid_1's auc: 0.711557
# Early stopping, best iteration is:
# [1638]	training's auc: 0.767336	valid_1's auc: 0.711939
# Fold  1 AUC : 0.711939
# Training until validation scores don't improve for 500 rounds.
# [1000]	training's auc: 0.75375	valid_1's auc: 0.719099
# Early stopping, best iteration is:
# [1040]	training's auc: 0.754536	valid_1's auc: 0.719389
# Fold  2 AUC : 0.719355
# Training until validation scores don't improve for 500 rounds.
# [1000]	training's auc: 0.755451	valid_1's auc: 0.713426
# Early stopping, best iteration is:
# [1382]	training's auc: 0.762311	valid_1's auc: 0.714811
# Fold  3 AUC : 0.714795
# Training until validation scores don't improve for 500 rounds.
# [1000]	training's auc: 0.755634	valid_1's auc: 0.709753
# Early stopping, best iteration is:
# [1286]	training's auc: 0.760939	valid_1's auc: 0.710463
# Fold  4 AUC : 0.710463
# Training until validation scores don't improve for 500 rounds.
# [1000]	training's auc: 0.753336	valid_1's auc: 0.728527
# Early stopping, best iteration is:
# [662]	training's auc: 0.744841	valid_1's auc: 0.729232
# Fold  5 AUC : 0.729232
# Full AUC score 0.716640
# |  3        |  0.7166   |  0.3649   |  0.6154   |  0.08392  |  71.1     |  4.733e+0 |  0.6514   |  0.000204 |  32.61    |  0.3168   |  0.5681   |
# Training until validation scores don't improve for 500 rounds.
# [1000]	training's auc: 0.790268	valid_1's auc: 0.724563
# Early stopping, best iteration is:
# [1205]	training's auc: 0.797491	valid_1's auc: 0.725697
# Fold  1 AUC : 0.725697
# Training until validation scores don't improve for 500 rounds.
# [1000]	training's auc: 0.788355	valid_1's auc: 0.725633
# Early stopping, best iteration is:
# [1096]	training's auc: 0.79134	valid_1's auc: 0.726272
# Fold  2 AUC : 0.726143
# Training until validation scores don't improve for 500 rounds.
# [1000]	training's auc: 0.790987	valid_1's auc: 0.718519
# [2000]	training's auc: 0.817953	valid_1's auc: 0.719291
# Early stopping, best iteration is:
# [1675]	training's auc: 0.810245	valid_1's auc: 0.719823
# Fold  3 AUC : 0.720167
# Training until validation scores don't improve for 500 rounds.
# [1000]	training's auc: 0.788654	valid_1's auc: 0.720195
# [2000]	training's auc: 0.815892	valid_1's auc: 0.719692
# Early stopping, best iteration is:
# [1528]	training's auc: 0.804369	valid_1's auc: 0.720463
# Fold  4 AUC : 0.720463
# Training until validation scores don't improve for 500 rounds.
# Early stopping, best iteration is:
# [436]	training's auc: 0.760939	valid_1's auc: 0.7351
# Fold  5 AUC : 0.735100
# Full AUC score 0.724680
# |  4        |  0.7247   |  0.8691   |  0.4362   |  0.411    |  42.97    |  3.817e+0 |  0.7046   |  0.000117 |  37.37    |  0.4421   |  0.9093   |
# Training until validation scores don't improve for 500 rounds.
# [1000]	training's auc: 0.811891	valid_1's auc: 0.723806
# Early stopping, best iteration is:
# [862]	training's auc: 0.804905	valid_1's auc: 0.72479
# Fold  1 AUC : 0.724793
# Training until validation scores don't improve for 500 rounds.
# [1000]	training's auc: 0.81026	valid_1's auc: 0.720468
# Early stopping, best iteration is:
# [699]	training's auc: 0.79451	valid_1's auc: 0.72193
# Fold  2 AUC : 0.721930
# Training until validation scores don't improve for 500 rounds.
# [1000]	training's auc: 0.811301	valid_1's auc: 0.721021
# Early stopping, best iteration is:
# [706]	training's auc: 0.796028	valid_1's auc: 0.722537
# Fold  3 AUC : 0.722606
# Training until validation scores don't improve for 500 rounds.
# [1000]	training's auc: 0.811112	valid_1's auc: 0.723712
# Early stopping, best iteration is:
# [742]	training's auc: 0.796949	valid_1's auc: 0.725154
# Fold  4 AUC : 0.725155
# Training until validation scores don't improve for 500 rounds.
# [1000]	training's auc: 0.808572	valid_1's auc: 0.732283
# Early stopping, best iteration is:
# [552]	training's auc: 0.782484	valid_1's auc: 0.735682
# Fold  5 AUC : 0.735682
# Full AUC score 0.725631
# |  5        |  0.7256   |  0.05981  |  0.1843   |  0.07131  |  109.4    |  3.378e+0 |  0.5333   |  3.123e-0 |  24.65    |  0.3297   |  0.503    |
# Training until validation scores don't improve for 500 rounds.
# [1000]	training's auc: 0.805103	valid_1's auc: 0.723822
# Early stopping, best iteration is:
# [910]	training's auc: 0.800352	valid_1's auc: 0.724285
# Fold  1 AUC : 0.724289
# Training until validation scores don't improve for 500 rounds.
# [1000]	training's auc: 0.802514	valid_1's auc: 0.720769
# Early stopping, best iteration is:
# [632]	training's auc: 0.784498	valid_1's auc: 0.72238
# Fold  2 AUC : 0.722263
# Training until validation scores don't improve for 500 rounds.
# [1000]	training's auc: 0.805261	valid_1's auc: 0.720172
# Early stopping, best iteration is:
# [851]	training's auc: 0.798596	valid_1's auc: 0.720461
# Fold  3 AUC : 0.720573
# Training until validation scores don't improve for 500 rounds.
# [1000]	training's auc: 0.804795	valid_1's auc: 0.723313
# Early stopping, best iteration is:
# [786]	training's auc: 0.794903	valid_1's auc: 0.724038
# Fold  4 AUC : 0.724050
# Training until validation scores don't improve for 500 rounds.
# [1000]	training's auc: 0.802574	valid_1's auc: 0.733492
# Early stopping, best iteration is:
# [586]	training's auc: 0.780802	valid_1's auc: 0.737268
# Fold  5 AUC : 0.737268
# Full AUC score 0.725337
# |  6        |  0.7253   |  0.1119   |  0.6072   |  0.3047   |  25.85    |  3.47e+03 |  0.9121   |  0.000397 |  39.72    |  0.9588   |  0.792    |
# Training until validation scores don't improve for 500 rounds.
# [1000]	training's auc: 0.859646	valid_1's auc: 0.725753
# Early stopping, best iteration is:
# [571]	training's auc: 0.824413	valid_1's auc: 0.729619
# Fold  1 AUC : 0.729626
# Training until validation scores don't improve for 500 rounds.
# Early stopping, best iteration is:
# [265]	training's auc: 0.787282	valid_1's auc: 0.728147
# Fold  2 AUC : 0.728147
# Training until validation scores don't improve for 500 rounds.
# Early stopping, best iteration is:
# [278]	training's auc: 0.791786	valid_1's auc: 0.723254
# Fold  3 AUC : 0.723254
# Training until validation scores don't improve for 500 rounds.
# Early stopping, best iteration is:
# [289]	training's auc: 0.792536	valid_1's auc: 0.724107
# Fold  4 AUC : 0.724109
# Training until validation scores don't improve for 500 rounds.
# Early stopping, best iteration is:
# [274]	training's auc: 0.786049	valid_1's auc: 0.74037
# Fold  5 AUC : 0.740370
# Full AUC score 0.728679
# |  7        |  0.7287   |  0.2853   |  0.6249   |  0.2651   |  49.46    |  2.529e+0 |  0.05387  |  0.000231 |  39.37    |  0.1239   |  0.1194   |
# Training until validation scores don't improve for 500 rounds.
# Early stopping, best iteration is:
# [340]	training's auc: 0.827656	valid_1's auc: 0.732972
# Fold  1 AUC : 0.732972
# Training until validation scores don't improve for 500 rounds.
# Early stopping, best iteration is:
# [179]	training's auc: 0.794812	valid_1's auc: 0.73299
# Fold  2 AUC : 0.732990
# Training until validation scores don't improve for 500 rounds.
# Early stopping, best iteration is:
# [165]	training's auc: 0.791588	valid_1's auc: 0.728919
# Fold  3 AUC : 0.728919
# Training until validation scores don't improve for 500 rounds.
# Early stopping, best iteration is:
# [373]	training's auc: 0.835093	valid_1's auc: 0.730149
# Fold  4 AUC : 0.730150
# Training until validation scores don't improve for 500 rounds.
# Early stopping, best iteration is:
# [211]	training's auc: 0.800691	valid_1's auc: 0.738733
# Fold  5 AUC : 0.738733
# Full AUC score 0.732395
# |  8        |  0.7324   |  0.7385   |  0.5873   |  0.2622   |  38.39    |  1.917e+0 |  0.9      |  0.000214 |  23.75    |  0.006209 |  0.3006   |
# Training until validation scores don't improve for 500 rounds.
# [1000]	training's auc: 0.794803	valid_1's auc: 0.726282
# Early stopping, best iteration is:
# [1186]	training's auc: 0.801106	valid_1's auc: 0.727479
# Fold  1 AUC : 0.727479
# Training until validation scores don't improve for 500 rounds.
# [1000]	training's auc: 0.792553	valid_1's auc: 0.726879
# Early stopping, best iteration is:
# [664]	training's auc: 0.779376	valid_1's auc: 0.72745
# Fold  2 AUC : 0.727450
# Training until validation scores don't improve for 500 rounds.
# [1000]	training's auc: 0.79566	valid_1's auc: 0.71999
# Early stopping, best iteration is:
# [896]	training's auc: 0.791951	valid_1's auc: 0.720561
# Fold  3 AUC : 0.720722
# Training until validation scores don't improve for 500 rounds.
# [1000]	training's auc: 0.792755	valid_1's auc: 0.721999
# Early stopping, best iteration is:
# [1200]	training's auc: 0.799856	valid_1's auc: 0.722627
# Fold  4 AUC : 0.722627
# Training until validation scores don't improve for 500 rounds.
# [1000]	training's auc: 0.792502	valid_1's auc: 0.732773
# Early stopping, best iteration is:
# [607]	training's auc: 0.774135	valid_1's auc: 0.735024
# Fold  5 AUC : 0.735024
# Full AUC score 0.726203
# |  9        |  0.7262   |  0.4369   |  0.6121   |  0.4632   |  103.2    |  3.824e+0 |  0.1498   |  0.000375 |  34.09    |  0.6337   |  0.4383   |
# Training until validation scores don't improve for 500 rounds.
# Early stopping, best iteration is:
# [444]	training's auc: 0.79457	valid_1's auc: 0.727561
# Fold  1 AUC : 0.727565
# Training until validation scores don't improve for 500 rounds.
# Early stopping, best iteration is:
# [364]	training's auc: 0.786797	valid_1's auc: 0.726386
# Fold  2 AUC : 0.726386
# Training until validation scores don't improve for 500 rounds.
# [1000]	training's auc: 0.837508	valid_1's auc: 0.725139
# Early stopping, best iteration is:
# [526]	training's auc: 0.803869	valid_1's auc: 0.726561
# Fold  3 AUC : 0.726628
# Training until validation scores don't improve for 500 rounds.
# [1000]	training's auc: 0.83611	valid_1's auc: 0.728347
# Early stopping, best iteration is:
# [890]	training's auc: 0.829111	valid_1's auc: 0.729102
# Fold  4 AUC : 0.729104
# Training until validation scores don't improve for 500 rounds.
# Early stopping, best iteration is:
# [346]	training's auc: 0.781951	valid_1's auc: 0.737112
# Fold  5 AUC : 0.737112
# Full AUC score 0.728880
# |  10       |  0.7289   |  0.1526   |  0.5684   |  0.2877   |  143.9    |  2.921e+0 |  0.5026   |  0.000273 |  33.67    |  0.05712  |  0.6694   |
# Training until validation scores don't improve for 500 rounds.
# [1000]	training's auc: 0.820122	valid_1's auc: 0.72481
# Early stopping, best iteration is:
# [733]	training's auc: 0.804556	valid_1's auc: 0.725977
# Fold  1 AUC : 0.725980
# Training until validation scores don't improve for 500 rounds.
# Early stopping, best iteration is:
# [337]	training's auc: 0.772899	valid_1's auc: 0.725193
# Fold  2 AUC : 0.725193
# Training until validation scores don't improve for 500 rounds.
# [1000]	training's auc: 0.81939	valid_1's auc: 0.722402
# Early stopping, best iteration is:
# [871]	training's auc: 0.81235	valid_1's auc: 0.722625
# Fold  3 AUC : 0.722625
# Training until validation scores don't improve for 500 rounds.
# [1000]	training's auc: 0.818141	valid_1's auc: 0.724629
# Early stopping, best iteration is:
# [786]	training's auc: 0.805765	valid_1's auc: 0.725871
# Fold  4 AUC : 0.725871
# Training until validation scores don't improve for 500 rounds.
# Early stopping, best iteration is:
# [327]	training's auc: 0.768428	valid_1's auc: 0.739495
# Fold  5 AUC : 0.739490
# Full AUC score 0.727078
# |  11       |  0.7271   |  0.5777   |  0.06981  |  0.1641   |  36.44    |  3.028e+0 |  0.2549   |  0.000405 |  35.59    |  0.002157 |  0.6909   |
# Training until validation scores don't improve for 500 rounds.
# [1000]	training's auc: 0.755183	valid_1's auc: 0.712822
# [2000]	training's auc: 0.770034	valid_1's auc: 0.713945
# Early stopping, best iteration is:
# [1656]	training's auc: 0.765773	valid_1's auc: 0.714364
# Fold  1 AUC : 0.714364
# Training until validation scores don't improve for 500 rounds.
# [1000]	training's auc: 0.753192	valid_1's auc: 0.723286
# Early stopping, best iteration is:
# [1159]	training's auc: 0.756054	valid_1's auc: 0.723478
# Fold  2 AUC : 0.723376
# Training until validation scores don't improve for 500 rounds.
# [1000]	training's auc: 0.7543	valid_1's auc: 0.714338
# [2000]	training's auc: 0.769195	valid_1's auc: 0.715907
# [3000]	training's auc: 0.779241	valid_1's auc: 0.717029
# Early stopping, best iteration is:
# [3321]	training's auc: 0.781991	valid_1's auc: 0.717339
# Fold  3 AUC : 0.717355
# Training until validation scores don't improve for 500 rounds.
# [1000]	training's auc: 0.754711	valid_1's auc: 0.709513
# [2000]	training's auc: 0.769323	valid_1's auc: 0.711565
# Early stopping, best iteration is:
# [2185]	training's auc: 0.771437	valid_1's auc: 0.711829
# Fold  4 AUC : 0.711829
# Training until validation scores don't improve for 500 rounds.
# [1000]	training's auc: 0.752852	valid_1's auc: 0.727114
# Early stopping, best iteration is:
# [669]	training's auc: 0.744891	valid_1's auc: 0.727539
# Fold  5 AUC : 0.727539
# Full AUC score 0.718213
# |  12       |  0.7182   |  0.5758   |  0.9311   |  0.086    |  28.0     |  4.46e+03 |  0.333    |  0.00036  |  6.677    |  0.4523   |  0.6485   |
# Training until validation scores don't improve for 500 rounds.
# [1000]	training's auc: 0.816065	valid_1's auc: 0.723482
# Early stopping, best iteration is:
# [818]	training's auc: 0.806556	valid_1's auc: 0.724175
# Fold  1 AUC : 0.724178
# Training until validation scores don't improve for 500 rounds.
# [1000]	training's auc: 0.814641	valid_1's auc: 0.724749
# Early stopping, best iteration is:
# [986]	training's auc: 0.814056	valid_1's auc: 0.725035
# Fold  2 AUC : 0.725035
# Training until validation scores don't improve for 500 rounds.
# [1000]	training's auc: 0.815793	valid_1's auc: 0.722322
# Early stopping, best iteration is:
# [980]	training's auc: 0.814829	valid_1's auc: 0.723142
# Fold  3 AUC : 0.723142
# Training until validation scores don't improve for 500 rounds.
# [1000]	training's auc: 0.81593	valid_1's auc: 0.726095
# Early stopping, best iteration is:
# [717]	training's auc: 0.799969	valid_1's auc: 0.727219
# Fold  4 AUC : 0.727219
# Training until validation scores don't improve for 500 rounds.
# Early stopping, best iteration is:
# [359]	training's auc: 0.770621	valid_1's auc: 0.73749
# Fold  5 AUC : 0.737490
# Full AUC score 0.726827
# |  13       |  0.7268   |  0.291    |  0.8077   |  0.1038   |  48.49    |  3.146e+0 |  0.9437   |  0.000222 |  36.28    |  0.3896   |  0.4767   |
# Training until validation scores don't improve for 500 rounds.
# Early stopping, best iteration is:
# [63]	training's auc: 0.785563	valid_1's auc: 0.73363
# Fold  1 AUC : 0.733630
# Training until validation scores don't improve for 500 rounds.
# Early stopping, best iteration is:
# [54]	training's auc: 0.781136	valid_1's auc: 0.729153
# Fold  2 AUC : 0.729153
# Training until validation scores don't improve for 500 rounds.
# Early stopping, best iteration is:
# [149]	training's auc: 0.833021	valid_1's auc: 0.727693
# Fold  3 AUC : 0.727693
# Training until validation scores don't improve for 500 rounds.
# Early stopping, best iteration is:
# [99]	training's auc: 0.80757	valid_1's auc: 0.728078
# Fold  4 AUC : 0.728078
# Training until validation scores don't improve for 500 rounds.
# Early stopping, best iteration is:
# [97]	training's auc: 0.80656	valid_1's auc: 0.745101
# Fold  5 AUC : 0.745101
# Full AUC score 0.732175
# |  14       |  0.7322   |  0.9781   |  0.4365   |  0.2186   |  91.71    |  1.188e+0 |  0.161    |  0.000215 |  14.79    |  0.3172   |  0.2173   |
# Training until validation scores don't improve for 500 rounds.
# [1000]	training's auc: 0.81223	valid_1's auc: 0.72401
# Early stopping, best iteration is:
# [775]	training's auc: 0.80005	valid_1's auc: 0.725077
# Fold  1 AUC : 0.725078
# Training until validation scores don't improve for 500 rounds.
# [1000]	training's auc: 0.809966	valid_1's auc: 0.724069
# Early stopping, best iteration is:
# [928]	training's auc: 0.806679	valid_1's auc: 0.72467
# Fold  2 AUC : 0.724545
# Training until validation scores don't improve for 500 rounds.
# [1000]	training's auc: 0.809683	valid_1's auc: 0.717511
# Early stopping, best iteration is:
# [778]	training's auc: 0.79875	valid_1's auc: 0.718401
# Fold  3 AUC : 0.718401
# Training until validation scores don't improve for 500 rounds.
# [1000]	training's auc: 0.809127	valid_1's auc: 0.724598
# Early stopping, best iteration is:
# [975]	training's auc: 0.807882	valid_1's auc: 0.724695
# Fold  4 AUC : 0.724695
# Training until validation scores don't improve for 500 rounds.
# Early stopping, best iteration is:
# [416]	training's auc: 0.77292	valid_1's auc: 0.738105
# Fold  5 AUC : 0.738099
# Full AUC score 0.725548
# |  15       |  0.7255   |  0.4214   |  0.6319   |  0.3382   |  81.33    |  3.548e+0 |  0.2553   |  0.000182 |  21.05    |  0.5429   |  0.4014   |
# Training until validation scores don't improve for 500 rounds.
# Early stopping, best iteration is:
# [177]	training's auc: 0.826157	valid_1's auc: 0.733805
# Fold  1 AUC : 0.733969
# Training until validation scores don't improve for 500 rounds.
# Early stopping, best iteration is:
# [112]	training's auc: 0.799404	valid_1's auc: 0.732229
# Fold  2 AUC : 0.732229
# Training until validation scores don't improve for 500 rounds.
# Early stopping, best iteration is:
# [114]	training's auc: 0.802419	valid_1's auc: 0.72984
# Fold  3 AUC : 0.729840
# Training until validation scores don't improve for 500 rounds.
# Early stopping, best iteration is:
# [317]	training's auc: 0.87016	valid_1's auc: 0.727421
# Fold  4 AUC : 0.727421
# Training until validation scores don't improve for 500 rounds.
# Early stopping, best iteration is:
# [134]	training's auc: 0.808814	valid_1's auc: 0.74126
# Fold  5 AUC : 0.741260
# Full AUC score 0.732196
# |  16       |  0.7322   |  0.04942  |  0.3719   |  0.3796   |  126.4    |  1.48e+03 |  0.2134   |  0.000441 |  17.75    |  0.4982   |  0.6753   |
# Training until validation scores don't improve for 500 rounds.
# Early stopping, best iteration is:
# [141]	training's auc: 0.797246	valid_1's auc: 0.738307
# Fold  1 AUC : 0.738307
# Training until validation scores don't improve for 500 rounds.
# Early stopping, best iteration is:
# [250]	training's auc: 0.830594	valid_1's auc: 0.731974
# Fold  2 AUC : 0.731974
# Training until validation scores don't improve for 500 rounds.
# Early stopping, best iteration is:
# [145]	training's auc: 0.799474	valid_1's auc: 0.732646
# Fold  3 AUC : 0.732646
# Training until validation scores don't improve for 500 rounds.
# Early stopping, best iteration is:
# [259]	training's auc: 0.834686	valid_1's auc: 0.726357
# Fold  4 AUC : 0.726358
# Training until validation scores don't improve for 500 rounds.
# Early stopping, best iteration is:
# [161]	training's auc: 0.803675	valid_1's auc: 0.741015
# Fold  5 AUC : 0.741015
# Full AUC score 0.733649
# |  17       |  0.7336   |  0.9271   |  0.9213   |  0.1777   |  144.8    |  1.665e+0 |  0.4957   |  0.000202 |  19.22    |  0.4839   |  0.9321   |
# Training until validation scores don't improve for 500 rounds.
# Early stopping, best iteration is:
# [231]	training's auc: 0.798107	valid_1's auc: 0.733982
# Fold  1 AUC : 0.733982
# Training until validation scores don't improve for 500 rounds.
# Early stopping, best iteration is:
# [153]	training's auc: 0.780848	valid_1's auc: 0.730537
# Fold  2 AUC : 0.730537
# Training until validation scores don't improve for 500 rounds.
# Early stopping, best iteration is:
# [233]	training's auc: 0.799498	valid_1's auc: 0.726238
# Fold  3 AUC : 0.726238
# Training until validation scores don't improve for 500 rounds.
# Early stopping, best iteration is:
# [310]	training's auc: 0.813546	valid_1's auc: 0.726306
# Fold  4 AUC : 0.726306
# Training until validation scores don't improve for 500 rounds.
# Early stopping, best iteration is:
# [271]	training's auc: 0.804503	valid_1's auc: 0.740709
# Fold  5 AUC : 0.740709
# Full AUC score 0.731229
# |  18       |  0.7312   |  0.03276  |  0.02451  |  0.3039   |  98.33    |  2.193e+0 |  0.1323   |  2.775e-0 |  10.25    |  0.5481   |  0.4054   |
# Training until validation scores don't improve for 500 rounds.
# [1000]	training's auc: 0.813362	valid_1's auc: 0.722967
# Early stopping, best iteration is:
# [547]	training's auc: 0.785946	valid_1's auc: 0.724409
# Fold  1 AUC : 0.724409
# Training until validation scores don't improve for 500 rounds.
# [1000]	training's auc: 0.813392	valid_1's auc: 0.723478
# Early stopping, best iteration is:
# [1096]	training's auc: 0.817385	valid_1's auc: 0.724204
# Fold  2 AUC : 0.724204
# Training until validation scores don't improve for 500 rounds.
# Early stopping, best iteration is:
# [478]	training's auc: 0.78275	valid_1's auc: 0.719097
# Fold  3 AUC : 0.719097
# Training until validation scores don't improve for 500 rounds.
# [1000]	training's auc: 0.81291	valid_1's auc: 0.725123
# Early stopping, best iteration is:
# [683]	training's auc: 0.794904	valid_1's auc: 0.726148
# Fold  4 AUC : 0.726148
# Training until validation scores don't improve for 500 rounds.
# Early stopping, best iteration is:
# [421]	training's auc: 0.773902	valid_1's auc: 0.739217
# Fold  5 AUC : 0.739217
# Full AUC score 0.726142
# |  19       |  0.7261   |  0.5843   |  0.3095   |  0.1003   |  145.3    |  3.431e+0 |  0.1546   |  0.000219 |  11.25    |  0.1156   |  0.3399   |
# Training until validation scores don't improve for 500 rounds.
# [1000]	training's auc: 0.775423	valid_1's auc: 0.721928
# [2000]	training's auc: 0.798038	valid_1's auc: 0.724398
# Early stopping, best iteration is:
# [1955]	training's auc: 0.797256	valid_1's auc: 0.724583
# Fold  1 AUC : 0.724583
# Training until validation scores don't improve for 500 rounds.
# [1000]	training's auc: 0.774893	valid_1's auc: 0.727436
# Early stopping, best iteration is:
# [1108]	training's auc: 0.777946	valid_1's auc: 0.72796
# Fold  2 AUC : 0.727960
# Training until validation scores don't improve for 500 rounds.
# [1000]	training's auc: 0.777983	valid_1's auc: 0.71509
# [2000]	training's auc: 0.799239	valid_1's auc: 0.716865
# Early stopping, best iteration is:
# [1795]	training's auc: 0.79566	valid_1's auc: 0.717506
# Fold  3 AUC : 0.717506
# Training until validation scores don't improve for 500 rounds.
# [1000]	training's auc: 0.773373	valid_1's auc: 0.719401
# Early stopping, best iteration is:
# [1174]	training's auc: 0.778245	valid_1's auc: 0.720615
# Fold  4 AUC : 0.720615
# Training until validation scores don't improve for 500 rounds.
# [1000]	training's auc: 0.774342	valid_1's auc: 0.734199
# Early stopping, best iteration is:
# [507]	training's auc: 0.756797	valid_1's auc: 0.735399
# Fold  5 AUC : 0.735399
# Full AUC score 0.724509
# |  20       |  0.7245   |  0.9533   |  0.1965   |  0.2704   |  149.4    |  3.97e+03 |  0.9035   |  0.000129 |  27.48    |  0.1183   |  0.5469   |
# Training until validation scores don't improve for 500 rounds.
# Early stopping, best iteration is:
# [112]	training's auc: 0.785482	valid_1's auc: 0.737376
# Fold  1 AUC : 0.737376
# Training until validation scores don't improve for 500 rounds.
# Early stopping, best iteration is:
# [106]	training's auc: 0.784295	valid_1's auc: 0.728892
# Fold  2 AUC : 0.728892
# Training until validation scores don't improve for 500 rounds.
# Early stopping, best iteration is:
# [147]	training's auc: 0.798386	valid_1's auc: 0.72804
# Fold  3 AUC : 0.728040
# Training until validation scores don't improve for 500 rounds.
# Early stopping, best iteration is:
# [137]	training's auc: 0.796885	valid_1's auc: 0.728421
# Fold  4 AUC : 0.728421
# Training until validation scores don't improve for 500 rounds.
# Early stopping, best iteration is:
# [197]	training's auc: 0.812193	valid_1's auc: 0.741629
# Fold  5 AUC : 0.741629
# Full AUC score 0.732611
# |  21       |  0.7326   |  0.7227   |  0.3857   |  0.4042   |  110.9    |  1.79e+03 |  0.2676   |  0.000280 |  15.12    |  0.8525   |  0.1884   |
# Training until validation scores don't improve for 500 rounds.
# [1000]	training's auc: 0.821043	valid_1's auc: 0.723855
# Early stopping, best iteration is:
# [562]	training's auc: 0.79325	valid_1's auc: 0.725587
# Fold  1 AUC : 0.725587
# Training until validation scores don't improve for 500 rounds.
# [1000]	training's auc: 0.820186	valid_1's auc: 0.722935
# Early stopping, best iteration is:
# [516]	training's auc: 0.789471	valid_1's auc: 0.725161
# Fold  2 AUC : 0.725161
# Training until validation scores don't improve for 500 rounds.
# [1000]	training's auc: 0.819611	valid_1's auc: 0.720918
# Early stopping, best iteration is:
# [878]	training's auc: 0.813192	valid_1's auc: 0.72129
# Fold  3 AUC : 0.721460
# Training until validation scores don't improve for 500 rounds.
# [1000]	training's auc: 0.820966	valid_1's auc: 0.727943
# Early stopping, best iteration is:
# [892]	training's auc: 0.81516	valid_1's auc: 0.729117
# Fold  4 AUC : 0.729117
# Training until validation scores don't improve for 500 rounds.
# Early stopping, best iteration is:
# [213]	training's auc: 0.758658	valid_1's auc: 0.736273
# Fold  5 AUC : 0.736273
# Full AUC score 0.726639
# |  22       |  0.7266   |  0.7055   |  0.3303   |  0.3758   |  101.0    |  3.359e+0 |  0.7472   |  8.703e-0 |  33.97    |  0.6077   |  0.5688   |
# Training until validation scores don't improve for 500 rounds.
# [1000]	training's auc: 0.757045	valid_1's auc: 0.710765
# [2000]	training's auc: 0.773069	valid_1's auc: 0.711631
# Early stopping, best iteration is:
# [1782]	training's auc: 0.770172	valid_1's auc: 0.712048
# Fold  1 AUC : 0.712048
# Training until validation scores don't improve for 500 rounds.
# [1000]	training's auc: 0.753905	valid_1's auc: 0.717747
# Early stopping, best iteration is:
# [872]	training's auc: 0.751177	valid_1's auc: 0.718017
# Fold  2 AUC : 0.718027
# Training until validation scores don't improve for 500 rounds.
# [1000]	training's auc: 0.756147	valid_1's auc: 0.711722
# Early stopping, best iteration is:
# [1412]	training's auc: 0.763467	valid_1's auc: 0.712612
# Fold  3 AUC : 0.712616
# Training until validation scores don't improve for 500 rounds.
# [1000]	training's auc: 0.756738	valid_1's auc: 0.712215
# Early stopping, best iteration is:
# [1167]	training's auc: 0.759925	valid_1's auc: 0.71238
# Fold  4 AUC : 0.712380
# Training until validation scores don't improve for 500 rounds.
# [1000]	training's auc: 0.753754	valid_1's auc: 0.72815
# Early stopping, best iteration is:
# [817]	training's auc: 0.749537	valid_1's auc: 0.728647
# Fold  5 AUC : 0.728647
# Full AUC score 0.716356
# |  23       |  0.7164   |  0.444    |  0.3636   |  0.2498   |  144.2    |  4.826e+0 |  0.9027   |  0.000412 |  9.836    |  0.4909   |  0.6995   |
# Training until validation scores don't improve for 500 rounds.
# [1000]	training's auc: 0.814485	valid_1's auc: 0.724194
# Early stopping, best iteration is:
# [573]	training's auc: 0.789032	valid_1's auc: 0.725739
# Fold  1 AUC : 0.725739
# Training until validation scores don't improve for 500 rounds.
# [1000]	training's auc: 0.814335	valid_1's auc: 0.723937
# Early stopping, best iteration is:
# [617]	training's auc: 0.792803	valid_1's auc: 0.726087
# Fold  2 AUC : 0.726087
# Training until validation scores don't improve for 500 rounds.
# [1000]	training's auc: 0.814704	valid_1's auc: 0.719962
# Early stopping, best iteration is:
# [843]	training's auc: 0.80633	valid_1's auc: 0.720712
# Fold  3 AUC : 0.720916
# Training until validation scores don't improve for 500 rounds.
# [1000]	training's auc: 0.8152	valid_1's auc: 0.723693
# Early stopping, best iteration is:
# [904]	training's auc: 0.810398	valid_1's auc: 0.72435
# Fold  4 AUC : 0.724350
# Training until validation scores don't improve for 500 rounds.
# [1000]	training's auc: 0.812374	valid_1's auc: 0.735492
# Early stopping, best iteration is:
# [589]	training's auc: 0.788039	valid_1's auc: 0.737062
# Fold  5 AUC : 0.737062
# Full AUC score 0.726391
# |  24       |  0.7264   |  0.7445   |  0.859    |  0.07103  |  62.12    |  3.166e+0 |  0.4424   |  0.000437 |  10.79    |  0.164    |  0.1278   |
# Training until validation scores don't improve for 500 rounds.
# Early stopping, best iteration is:
# [456]	training's auc: 0.810188	valid_1's auc: 0.727941
# Fold  1 AUC : 0.727941
# Training until validation scores don't improve for 500 rounds.
# Early stopping, best iteration is:
# [286]	training's auc: 0.790458	valid_1's auc: 0.728146
# Fold  2 AUC : 0.728062
# Training until validation scores don't improve for 500 rounds.
# Early stopping, best iteration is:
# [192]	training's auc: 0.779024	valid_1's auc: 0.725953
# Fold  3 AUC : 0.725953
# Training until validation scores don't improve for 500 rounds.
# [1000]	training's auc: 0.856381	valid_1's auc: 0.723348
# Early stopping, best iteration is:
# [957]	training's auc: 0.853249	valid_1's auc: 0.724394
# Fold  4 AUC : 0.724400
# Training until validation scores don't improve for 500 rounds.
# Early stopping, best iteration is:
# [355]	training's auc: 0.796628	valid_1's auc: 0.738848
# Fold  5 AUC : 0.738848
# Full AUC score 0.728263
# |  25       |  0.7283   |  0.139    |  0.3233   |  0.4647   |  50.87    |  2.62e+03 |  0.3955   |  9.37e-05 |  36.69    |  0.8423   |  0.3352   |
# Training until validation scores don't improve for 500 rounds.
# [1000]	training's auc: 0.847218	valid_1's auc: 0.729844
# Early stopping, best iteration is:
# [590]	training's auc: 0.816882	valid_1's auc: 0.732695
# Fold  1 AUC : 0.732695
# Training until validation scores don't improve for 500 rounds.
# Early stopping, best iteration is:
# [218]	training's auc: 0.777419	valid_1's auc: 0.727682
# Fold  2 AUC : 0.727531
# Training until validation scores don't improve for 500 rounds.
# Early stopping, best iteration is:
# [299]	training's auc: 0.789879	valid_1's auc: 0.726652
# Fold  3 AUC : 0.726652
# Training until validation scores don't improve for 500 rounds.
# Early stopping, best iteration is:
# [376]	training's auc: 0.796918	valid_1's auc: 0.726612
# Fold  4 AUC : 0.726612
# Training until validation scores don't improve for 500 rounds.
# Early stopping, best iteration is:
# [283]	training's auc: 0.780949	valid_1's auc: 0.739789
# Fold  5 AUC : 0.739789
# Full AUC score 0.730299
# |  26       |  0.7303   |  0.9196   |  0.5972   |  0.3274   |  46.28    |  2.695e+0 |  0.6998   |  0.000149 |  21.62    |  0.2531   |  0.229    |
# Training until validation scores don't improve for 500 rounds.
# Early stopping, best iteration is:
# [246]	training's auc: 0.796704	valid_1's auc: 0.731668
# Fold  1 AUC : 0.731668
# Training until validation scores don't improve for 500 rounds.
# Early stopping, best iteration is:
# [307]	training's auc: 0.807355	valid_1's auc: 0.729881
# Fold  2 AUC : 0.729881
# Training until validation scores don't improve for 500 rounds.
# Early stopping, best iteration is:
# [116]	training's auc: 0.769624	valid_1's auc: 0.725207
# Fold  3 AUC : 0.725207
# Training until validation scores don't improve for 500 rounds.
# Early stopping, best iteration is:
# [256]	training's auc: 0.799199	valid_1's auc: 0.728609
# Fold  4 AUC : 0.728609
# Training until validation scores don't improve for 500 rounds.
# Early stopping, best iteration is:
# [303]	training's auc: 0.805281	valid_1's auc: 0.740135
# Fold  5 AUC : 0.740135
# Full AUC score 0.730810
# |  27       |  0.7308   |  0.8241   |  0.5865   |  0.1707   |  99.68    |  2.201e+0 |  0.9486   |  0.000212 |  32.66    |  0.867    |  0.5053   |
# Training until validation scores don't improve for 500 rounds.
# [1000]	training's auc: 0.823063	valid_1's auc: 0.723972
# Early stopping, best iteration is:
# [623]	training's auc: 0.799831	valid_1's auc: 0.725304
# Fold  1 AUC : 0.725304
# Training until validation scores don't improve for 500 rounds.
# [1000]	training's auc: 0.821473	valid_1's auc: 0.724903
# Early stopping, best iteration is:
# [519]	training's auc: 0.791064	valid_1's auc: 0.726165
# Fold  2 AUC : 0.726165
# Training until validation scores don't improve for 500 rounds.
# [1000]	training's auc: 0.823629	valid_1's auc: 0.719453
# Early stopping, best iteration is:
# [986]	training's auc: 0.82315	valid_1's auc: 0.719604
# Fold  3 AUC : 0.719809
# Training until validation scores don't improve for 500 rounds.
# [1000]	training's auc: 0.820867	valid_1's auc: 0.723717
# Early stopping, best iteration is:
# [616]	training's auc: 0.798318	valid_1's auc: 0.724771
# Fold  4 AUC : 0.724775
# Training until validation scores don't improve for 500 rounds.
# Early stopping, best iteration is:
# [380]	training's auc: 0.775987	valid_1's auc: 0.738159
# Fold  5 AUC : 0.738159
# Full AUC score 0.726144
# |  28       |  0.7261   |  0.5993   |  0.06584  |  0.4498   |  103.8    |  3.338e+0 |  0.1076   |  0.000376 |  15.84    |  0.04858  |  0.8269   |
# Training until validation scores don't improve for 500 rounds.
# Early stopping, best iteration is:
# [418]	training's auc: 0.774479	valid_1's auc: 0.724327
# Fold  1 AUC : 0.724327
# Training until validation scores don't improve for 500 rounds.
# Early stopping, best iteration is:
# [381]	training's auc: 0.771445	valid_1's auc: 0.723004
# Fold  2 AUC : 0.722911
# Training until validation scores don't improve for 500 rounds.
# [1000]	training's auc: 0.809975	valid_1's auc: 0.716046
# Early stopping, best iteration is:
# [1268]	training's auc: 0.821225	valid_1's auc: 0.71686
# Fold  3 AUC : 0.716860
# Training until validation scores don't improve for 500 rounds.
# [1000]	training's auc: 0.807636	valid_1's auc: 0.722522
# Early stopping, best iteration is:
# [735]	training's auc: 0.794486	valid_1's auc: 0.723172
# Fold  4 AUC : 0.723172
# Training until validation scores don't improve for 500 rounds.
# Early stopping, best iteration is:
# [376]	training's auc: 0.768378	valid_1's auc: 0.736874
# Fold  5 AUC : 0.736874
# Full AUC score 0.724147
# |  29       |  0.7241   |  0.3789   |  0.7993   |  0.328    |  44.8     |  3.516e+0 |  0.1365   |  0.000211 |  25.4     |  0.9013   |  0.7806   |
# Training until validation scores don't improve for 500 rounds.
# Early stopping, best iteration is:
# [188]	training's auc: 0.778255	valid_1's auc: 0.731539
# Fold  1 AUC : 0.731542
# Training until validation scores don't improve for 500 rounds.
# Early stopping, best iteration is:
# [378]	training's auc: 0.807655	valid_1's auc: 0.727512
# Fold  2 AUC : 0.727416
# Training until validation scores don't improve for 500 rounds.
# Early stopping, best iteration is:
# [196]	training's auc: 0.780599	valid_1's auc: 0.725554
# Fold  3 AUC : 0.725554
# Training until validation scores don't improve for 500 rounds.
# Early stopping, best iteration is:
# [337]	training's auc: 0.80317	valid_1's auc: 0.727277
# Fold  4 AUC : 0.727277
# Training until validation scores don't improve for 500 rounds.
# Early stopping, best iteration is:
# [137]	training's auc: 0.763935	valid_1's auc: 0.737084
# Fold  5 AUC : 0.737084
# Full AUC score 0.729038
# |  30       |  0.729    |  0.08895  |  0.3055   |  0.2314   |  143.6    |  2.517e+0 |  0.9559   |  0.000397 |  29.32    |  0.6278   |  0.7293   |
# =================================================================================================================================================

# %%
optimize_xgb(X_train, X_test, y_train, init_points=init_points, num_iter=num_iter,\
             num_params=num_params, stratify=stratify)
# Out:
# Bayesian optimization results will be stored in xgb_BO_res_optimization.dict after training...
# |   iter    |  target   | colsam... |   gamma   | max_depth | min_ch... | reg_alpha | reg_la... | scale_... | subsample |
# -------------------------------------------------------------------------------------------------------------------------
# [0]	train-auc:0.649969	eval-auc:0.646602
# Multiple eval metrics have been passed: 'eval-auc' will be used for early stopping.
#
# Will train until eval-auc hasn't improved in 100 rounds.
# [100]	train-auc:0.744072	eval-auc:0.730307
# [200]	train-auc:0.752086	eval-auc:0.733475
# [300]	train-auc:0.757017	eval-auc:0.733635
# [400]	train-auc:0.758905	eval-auc:0.734548
# [500]	train-auc:0.761267	eval-auc:0.734517
# Stopping. Best iteration:
# [411]	train-auc:0.759427	eval-auc:0.734724
#
# Fold  1 AUC : 0.734724
# [0]	train-auc:0.63862	eval-auc:0.635271
# Multiple eval metrics have been passed: 'eval-auc' will be used for early stopping.
#
# Will train until eval-auc hasn't improved in 100 rounds.
# [100]	train-auc:0.743265	eval-auc:0.732264
# [200]	train-auc:0.752032	eval-auc:0.735345
# [300]	train-auc:0.75673	eval-auc:0.735917
# [400]	train-auc:0.759809	eval-auc:0.73666
# [500]	train-auc:0.76186	eval-auc:0.737236
# [600]	train-auc:0.76337	eval-auc:0.737453
# [700]	train-auc:0.764121	eval-auc:0.737467
# [800]	train-auc:0.76517	eval-auc:0.737539
# [900]	train-auc:0.766455	eval-auc:0.737697
# Stopping. Best iteration:
# [824]	train-auc:0.765509	eval-auc:0.737764
#
# Fold  2 AUC : 0.737764
# [0]	train-auc:0.650975	eval-auc:0.642703
# Multiple eval metrics have been passed: 'eval-auc' will be used for early stopping.
#
# Will train until eval-auc hasn't improved in 100 rounds.
# [100]	train-auc:0.748527	eval-auc:0.711992
# [200]	train-auc:0.757072	eval-auc:0.715993
# [300]	train-auc:0.762154	eval-auc:0.717254
# [400]	train-auc:0.762893	eval-auc:0.717848
# [500]	train-auc:0.764888	eval-auc:0.71791
# [600]	train-auc:0.765313	eval-auc:0.718043
# Stopping. Best iteration:
# [520]	train-auc:0.765078	eval-auc:0.718244
#
# Fold  3 AUC : 0.718244
# [0]	train-auc:0.638186	eval-auc:0.641254
# Multiple eval metrics have been passed: 'eval-auc' will be used for early stopping.
#
# Will train until eval-auc hasn't improved in 100 rounds.
# [100]	train-auc:0.743713	eval-auc:0.72805
# [200]	train-auc:0.753109	eval-auc:0.732339
# [300]	train-auc:0.755532	eval-auc:0.733253
# [400]	train-auc:0.75714	eval-auc:0.733424
# [500]	train-auc:0.75795	eval-auc:0.733556
# [600]	train-auc:0.760246	eval-auc:0.734119
# Stopping. Best iteration:
# [594]	train-auc:0.759966	eval-auc:0.734193
#
# Fold  4 AUC : 0.734193
# Full AUC score 0.730935
# |  1        |  0.7309   |  0.2319   |  6.599    |  3.751    |  80.68    |  0.824    |  0.4181   |  0.2765   |  0.8118   |
# [0]	train-auc:0.680575	eval-auc:0.667105
# Multiple eval metrics have been passed: 'eval-auc' will be used for early stopping.
#
# Will train until eval-auc hasn't improved in 100 rounds.
# [100]	train-auc:0.748282	eval-auc:0.731955
# [200]	train-auc:0.759473	eval-auc:0.734145
# [300]	train-auc:0.764209	eval-auc:0.734849
# [400]	train-auc:0.766595	eval-auc:0.735572
# [500]	train-auc:0.770189	eval-auc:0.736676
# [600]	train-auc:0.772897	eval-auc:0.737125
# [700]	train-auc:0.775886	eval-auc:0.737151
# Stopping. Best iteration:
# [668]	train-auc:0.774669	eval-auc:0.737832
#
# Fold  1 AUC : 0.737833
# [0]	train-auc:0.674587	eval-auc:0.661477
# Multiple eval metrics have been passed: 'eval-auc' will be used for early stopping.
#
# Will train until eval-auc hasn't improved in 100 rounds.
# [100]	train-auc:0.749172	eval-auc:0.733979
# [200]	train-auc:0.760601	eval-auc:0.737083
# [300]	train-auc:0.767703	eval-auc:0.738478
# [400]	train-auc:0.773272	eval-auc:0.738622
# [500]	train-auc:0.777815	eval-auc:0.7397
# [600]	train-auc:0.779533	eval-auc:0.739784
# [700]	train-auc:0.781363	eval-auc:0.740116
# [800]	train-auc:0.78348	eval-auc:0.740105
# [900]	train-auc:0.784096	eval-auc:0.740153
# Stopping. Best iteration:
# [839]	train-auc:0.783845	eval-auc:0.740277
#
# Fold  2 AUC : 0.740277
# [0]	train-auc:0.674769	eval-auc:0.648449
# Multiple eval metrics have been passed: 'eval-auc' will be used for early stopping.
#
# Will train until eval-auc hasn't improved in 100 rounds.
# [100]	train-auc:0.753341	eval-auc:0.713693
# [200]	train-auc:0.763914	eval-auc:0.71793
# [300]	train-auc:0.769527	eval-auc:0.719785
# [400]	train-auc:0.773083	eval-auc:0.720418
# [500]	train-auc:0.776658	eval-auc:0.720234
# Stopping. Best iteration:
# [430]	train-auc:0.773975	eval-auc:0.721009
#
# Fold  3 AUC : 0.721009
# [0]	train-auc:0.673716	eval-auc:0.667676
# Multiple eval metrics have been passed: 'eval-auc' will be used for early stopping.
#
# Will train until eval-auc hasn't improved in 100 rounds.
# [100]	train-auc:0.749251	eval-auc:0.73013
# [200]	train-auc:0.759503	eval-auc:0.73246
# [300]	train-auc:0.763426	eval-auc:0.732762
# Stopping. Best iteration:
# [208]	train-auc:0.760204	eval-auc:0.733204
#
# Fold  4 AUC : 0.733204
# Full AUC score 0.732766
# |  2        |  0.7328   |  0.9602   |  8.883    |  3.431    |  55.09    |  0.7468   |  0.7702   |  0.3703   |  0.5831   |
# [0]	train-auc:0.618248	eval-auc:0.618372
# Multiple eval metrics have been passed: 'eval-auc' will be used for early stopping.
#
# Will train until eval-auc hasn't improved in 100 rounds.
# [100]	train-auc:0.677566	eval-auc:0.688847
# Stopping. Best iteration:
# [51]	train-auc:0.677629	eval-auc:0.688902
#
# Fold  1 AUC : 0.688902
# [0]	train-auc:0.5	eval-auc:0.5
# Multiple eval metrics have been passed: 'eval-auc' will be used for early stopping.
#
# Will train until eval-auc hasn't improved in 100 rounds.
# [100]	train-auc:0.676589	eval-auc:0.674875
# Stopping. Best iteration:
# [54]	train-auc:0.676589	eval-auc:0.674875
#
# Fold  2 AUC : 0.674875
# [0]	train-auc:0.5	eval-auc:0.5
# Multiple eval metrics have been passed: 'eval-auc' will be used for early stopping.
#
# Will train until eval-auc hasn't improved in 100 rounds.
# [100]	train-auc:0.691739	eval-auc:0.673336
# Stopping. Best iteration:
# [54]	train-auc:0.691739	eval-auc:0.673336
#
# Fold  3 AUC : 0.673336
# [0]	train-auc:0.5	eval-auc:0.5
# Multiple eval metrics have been passed: 'eval-auc' will be used for early stopping.
#
# Will train until eval-auc hasn't improved in 100 rounds.
# [100]	train-auc:0.684282	eval-auc:0.679869
# Stopping. Best iteration:
# [48]	train-auc:0.684898	eval-auc:0.680845
#
# Fold  4 AUC : 0.680845
# Full AUC score 0.662233
# |  3        |  0.6622   |  0.5279   |  1.124    |  5.091    |  89.44    |  0.4919   |  0.6923   |  0.07538  |  0.4004   |
# [0]	train-auc:0.687498	eval-auc:0.685433
# Multiple eval metrics have been passed: 'eval-auc' will be used for early stopping.
#
# Will train until eval-auc hasn't improved in 100 rounds.
# [100]	train-auc:0.761372	eval-auc:0.735542
# [200]	train-auc:0.789581	eval-auc:0.741217
# [300]	train-auc:0.811162	eval-auc:0.74065
# Stopping. Best iteration:
# [206]	train-auc:0.791209	eval-auc:0.741859
#
# Fold  1 AUC : 0.741859
# [0]	train-auc:0.676285	eval-auc:0.673437
# Multiple eval metrics have been passed: 'eval-auc' will be used for early stopping.
#
# Will train until eval-auc hasn't improved in 100 rounds.
# [100]	train-auc:0.760335	eval-auc:0.736331
# [200]	train-auc:0.788301	eval-auc:0.739196
# [300]	train-auc:0.810334	eval-auc:0.735903
# Stopping. Best iteration:
# [206]	train-auc:0.790065	eval-auc:0.739381
#
# Fold  2 AUC : 0.739381
# [0]	train-auc:0.697311	eval-auc:0.666493
# Multiple eval metrics have been passed: 'eval-auc' will be used for early stopping.
#
# Will train until eval-auc hasn't improved in 100 rounds.
# [100]	train-auc:0.764209	eval-auc:0.719143
# [200]	train-auc:0.793599	eval-auc:0.723596
# [300]	train-auc:0.815244	eval-auc:0.723415
# Stopping. Best iteration:
# [260]	train-auc:0.807349	eval-auc:0.724247
#
# Fold  3 AUC : 0.724247
# [0]	train-auc:0.690783	eval-auc:0.677784
# Multiple eval metrics have been passed: 'eval-auc' will be used for early stopping.
#
# Will train until eval-auc hasn't improved in 100 rounds.
# [100]	train-auc:0.762243	eval-auc:0.733503
# [200]	train-auc:0.791228	eval-auc:0.736002
# [300]	train-auc:0.810916	eval-auc:0.737167
# Stopping. Best iteration:
# [299]	train-auc:0.810728	eval-auc:0.737497
# Fold  4 AUC : 0.737497
# Full AUC score 0.735507
# |  4        |  0.7355   |  0.9365   |  6.862    |  3.589    |  80.99    |  0.4535   |  0.6545   |  0.8691   |  0.4644   |
# [0]	train-auc:0.70338	eval-auc:0.69706
# Multiple eval metrics have been passed: 'eval-auc' will be used for early stopping.
#
# Will train until eval-auc hasn't improved in 100 rounds.
# [100]	train-auc:0.770305	eval-auc:0.738098
# [200]	train-auc:0.804604	eval-auc:0.741666
# [300]	train-auc:0.831688	eval-auc:0.74188
# Stopping. Best iteration:
# [222]	train-auc:0.811429	eval-auc:0.742936
#
# Fold  1 AUC : 0.742936
# [0]	train-auc:0.705535	eval-auc:0.682703
# Multiple eval metrics have been passed: 'eval-auc' will be used for early stopping.
#
# Will train until eval-auc hasn't improved in 100 rounds.
# [100]	train-auc:0.768443	eval-auc:0.739137
# [200]	train-auc:0.802901	eval-auc:0.742078
# [300]	train-auc:0.830204	eval-auc:0.740931
# Stopping. Best iteration:
# [240]	train-auc:0.815245	eval-auc:0.742459
#
# Fold  2 AUC : 0.742459
# [0]	train-auc:0.711042	eval-auc:0.683238
# Multiple eval metrics have been passed: 'eval-auc' will be used for early stopping.
#
# Will train until eval-auc hasn't improved in 100 rounds.
# [100]	train-auc:0.776389	eval-auc:0.7189
# [200]	train-auc:0.808906	eval-auc:0.724585
# [300]	train-auc:0.835403	eval-auc:0.725431
# [400]	train-auc:0.855412	eval-auc:0.723227
# Stopping. Best iteration:
# [346]	train-auc:0.844528	eval-auc:0.725487
#
# Fold  3 AUC : 0.725487
# [0]	train-auc:0.704142	eval-auc:0.691174
# Multiple eval metrics have been passed: 'eval-auc' will be used for early stopping.
#
# Will train until eval-auc hasn't improved in 100 rounds.
# [100]	train-auc:0.771372	eval-auc:0.732942
# [200]	train-auc:0.803258	eval-auc:0.735377
# [300]	train-auc:0.83169	eval-auc:0.735577
# Stopping. Best iteration:
# [273]	train-auc:0.824793	eval-auc:0.736352
#
# Fold  4 AUC : 0.736352
# Full AUC score 0.736369
# |  5        |  0.7364   |  0.812    |  2.294    |  4.817    |  73.41    |  0.375    |  0.9399   |  0.4421   |  0.9139   |
# [0]	train-auc:0.5	eval-auc:0.5
# Multiple eval metrics have been passed: 'eval-auc' will be used for early stopping.
#
# Will train until eval-auc hasn't improved in 100 rounds.
# [100]	train-auc:0.671244	eval-auc:0.682186
# Stopping. Best iteration:
# [67]	train-auc:0.670864	eval-auc:0.683521
#
# Fold  1 AUC : 0.683521
# [0]	train-auc:0.5	eval-auc:0.5
# Multiple eval metrics have been passed: 'eval-auc' will be used for early stopping.
#
# Will train until eval-auc hasn't improved in 100 rounds.
# [100]	train-auc:0.675579	eval-auc:0.673133
# Stopping. Best iteration:
# [68]	train-auc:0.675579	eval-auc:0.673133
#
# Fold  2 AUC : 0.673133
# [0]	train-auc:0.5	eval-auc:0.5
# Multiple eval metrics have been passed: 'eval-auc' will be used for early stopping.
#
# Will train until eval-auc hasn't improved in 100 rounds.
# [100]	train-auc:0.678094	eval-auc:0.660506
# Stopping. Best iteration:
# [64]	train-auc:0.678472	eval-auc:0.661112
#
# Fold  3 AUC : 0.661112
# [0]	train-auc:0.5	eval-auc:0.5
# Multiple eval metrics have been passed: 'eval-auc' will be used for early stopping.
#
# Will train until eval-auc hasn't improved in 100 rounds.
# [100]	train-auc:0.680874	eval-auc:0.675348
# Stopping. Best iteration:
# [65]	train-auc:0.68154	eval-auc:0.675846
#
# Fold  4 AUC : 0.675846
# Full AUC score 0.663447
# |  6        |  0.6634   |  0.1068   |  2.659    |  2.189    |  70.74    |  0.6757   |  0.6266   |  0.04332  |  0.5834   |
# [0]	train-auc:0.670559	eval-auc:0.673868
# Multiple eval metrics have been passed: 'eval-auc' will be used for early stopping.
#
# Will train until eval-auc hasn't improved in 100 rounds.
# [100]	train-auc:0.750687	eval-auc:0.739714
# [200]	train-auc:0.769479	eval-auc:0.743996
# [300]	train-auc:0.784941	eval-auc:0.746342
# [400]	train-auc:0.796626	eval-auc:0.747233
# [500]	train-auc:0.807567	eval-auc:0.748136
# [600]	train-auc:0.816436	eval-auc:0.74711
# Stopping. Best iteration:
# [501]	train-auc:0.807798	eval-auc:0.748208
#
# Fold  1 AUC : 0.748208
# [0]	train-auc:0.636918	eval-auc:0.632161
# Multiple eval metrics have been passed: 'eval-auc' will be used for early stopping.
#
# Will train until eval-auc hasn't improved in 100 rounds.
# [100]	train-auc:0.749467	eval-auc:0.735841
# [200]	train-auc:0.769286	eval-auc:0.73987
# [300]	train-auc:0.785147	eval-auc:0.740442
# Stopping. Best iteration:
# [270]	train-auc:0.780454	eval-auc:0.741061
#
# Fold  2 AUC : 0.741061
# [0]	train-auc:0.674744	eval-auc:0.662486
# Multiple eval metrics have been passed: 'eval-auc' will be used for early stopping.
#
# Will train until eval-auc hasn't improved in 100 rounds.
# [100]	train-auc:0.754616	eval-auc:0.718084
# [200]	train-auc:0.773024	eval-auc:0.724496
# [300]	train-auc:0.787634	eval-auc:0.727087
# [400]	train-auc:0.800513	eval-auc:0.72784
# [500]	train-auc:0.812554	eval-auc:0.728399
# [600]	train-auc:0.821474	eval-auc:0.728756
# Stopping. Best iteration:
# [530]	train-auc:0.815785	eval-auc:0.729001
#
# Fold  3 AUC : 0.729001
# [0]	train-auc:0.666565	eval-auc:0.65125
# Multiple eval metrics have been passed: 'eval-auc' will be used for early stopping.
#
# Will train until eval-auc hasn't improved in 100 rounds.
# [100]	train-auc:0.751031	eval-auc:0.729875
# [200]	train-auc:0.769751	eval-auc:0.735208
# [300]	train-auc:0.785295	eval-auc:0.736959
# [400]	train-auc:0.798466	eval-auc:0.738017
# [500]	train-auc:0.808494	eval-auc:0.73962
# Stopping. Best iteration:
# [486]	train-auc:0.807055	eval-auc:0.739904
#
# Fold  4 AUC : 0.739904
# Full AUC score 0.739266
# |  7        |  0.7393   |  0.3632   |  5.527    |  2.448    |  64.65    |  0.6528   |  0.2054   |  0.6174   |  0.9165   |
# [0]	train-auc:0.623453	eval-auc:0.625359
# Multiple eval metrics have been passed: 'eval-auc' will be used for early stopping.
#
# Will train until eval-auc hasn't improved in 100 rounds.
# [100]	train-auc:0.729656	eval-auc:0.720357
# [200]	train-auc:0.733937	eval-auc:0.721924
# Stopping. Best iteration:
# [166]	train-auc:0.73285	eval-auc:0.722281
#
# Fold  1 AUC : 0.722281
# [0]	train-auc:0.623396	eval-auc:0.625531
# Multiple eval metrics have been passed: 'eval-auc' will be used for early stopping.
#
# Will train until eval-auc hasn't improved in 100 rounds.
# [100]	train-auc:0.72788	eval-auc:0.723093
# [200]	train-auc:0.731008	eval-auc:0.72358
# [300]	train-auc:0.735585	eval-auc:0.723934
# Stopping. Best iteration:
# [238]	train-auc:0.732562	eval-auc:0.724134
#
# Fold  2 AUC : 0.724134
# [0]	train-auc:0.621786	eval-auc:0.620345
# Multiple eval metrics have been passed: 'eval-auc' will be used for early stopping.
#
# Will train until eval-auc hasn't improved in 100 rounds.
# [100]	train-auc:0.733314	eval-auc:0.704098
# [200]	train-auc:0.737113	eval-auc:0.705883
# [300]	train-auc:0.7398	eval-auc:0.707939
# [400]	train-auc:0.74127	eval-auc:0.708626
# [500]	train-auc:0.742681	eval-auc:0.709531
# [600]	train-auc:0.744347	eval-auc:0.709516
# [700]	train-auc:0.745356	eval-auc:0.711043
# [800]	train-auc:0.747822	eval-auc:0.711783
# [900]	train-auc:0.748905	eval-auc:0.71186
# Stopping. Best iteration:
# [864]	train-auc:0.748655	eval-auc:0.712791
#
# Fold  3 AUC : 0.712791
# [0]	train-auc:0.667615	eval-auc:0.658538
# Multiple eval metrics have been passed: 'eval-auc' will be used for early stopping.
#
# Will train until eval-auc hasn't improved in 100 rounds.
# [100]	train-auc:0.727675	eval-auc:0.718241
# [200]	train-auc:0.732191	eval-auc:0.720993
# [300]	train-auc:0.735282	eval-auc:0.722676
# Stopping. Best iteration:
# [256]	train-auc:0.734165	eval-auc:0.723359
#
# Fold  4 AUC : 0.723359
# Full AUC score 0.719693
# |  8        |  0.7197   |  0.801    |  9.929    |  5.835    |  81.28    |  0.4282   |  0.6999   |  0.4781   |  0.2359   |
# [0]	train-auc:0.698911	eval-auc:0.695169
# Multiple eval metrics have been passed: 'eval-auc' will be used for early stopping.
#
# Will train until eval-auc hasn't improved in 100 rounds.
# [100]	train-auc:0.757697	eval-auc:0.737589
# [200]	train-auc:0.783686	eval-auc:0.742786
# [300]	train-auc:0.80454	eval-auc:0.743801
# Stopping. Best iteration:
# [297]	train-auc:0.803552	eval-auc:0.744175
# Fold  1 AUC : 0.744175
# [0]	train-auc:0.675822	eval-auc:0.664968
# Multiple eval metrics have been passed: 'eval-auc' will be used for early stopping.
#
# Will train until eval-auc hasn't improved in 100 rounds.
# [100]	train-auc:0.757203	eval-auc:0.735804
# [200]	train-auc:0.781812	eval-auc:0.739697
# [300]	train-auc:0.80387	eval-auc:0.738993
# Stopping. Best iteration:
# [268]	train-auc:0.797051	eval-auc:0.740695
#
# Fold  2 AUC : 0.740695
# [0]	train-auc:0.700697	eval-auc:0.673479
# Multiple eval metrics have been passed: 'eval-auc' will be used for early stopping.
#
# Will train until eval-auc hasn't improved in 100 rounds.
# [100]	train-auc:0.761801	eval-auc:0.715491
# [200]	train-auc:0.787153	eval-auc:0.720851
# [300]	train-auc:0.806852	eval-auc:0.723426
# Stopping. Best iteration:
# [266]	train-auc:0.800759	eval-auc:0.723844
#
# Fold  3 AUC : 0.723844
# [0]	train-auc:0.691785	eval-auc:0.696655
# Multiple eval metrics have been passed: 'eval-auc' will be used for early stopping.
#
# Will train until eval-auc hasn't improved in 100 rounds.
# [100]	train-auc:0.757633	eval-auc:0.73099
# [200]	train-auc:0.782349	eval-auc:0.734379
# [300]	train-auc:0.802409	eval-auc:0.735238
# Stopping. Best iteration:
# [294]	train-auc:0.801217	eval-auc:0.735577
#
# Fold  4 AUC : 0.735577
# Full AUC score 0.735836
# |  9        |  0.7358   |  0.4132   |  1.485    |  3.807    |  98.38    |  0.2992   |  0.2955   |  0.7385   |  0.6079   |
# [0]	train-auc:0.5	eval-auc:0.5
# Multiple eval metrics have been passed: 'eval-auc' will be used for early stopping.
#
# Will train until eval-auc hasn't improved in 100 rounds.
# [100]	train-auc:0.5	eval-auc:0.5
# Stopping. Best iteration:
# [0]	train-auc:0.5	eval-auc:0.5
#
# Fold  1 AUC : 0.500000
# [0]	train-auc:0.5	eval-auc:0.5
# Multiple eval metrics have been passed: 'eval-auc' will be used for early stopping.
#
# Will train until eval-auc hasn't improved in 100 rounds.
# [100]	train-auc:0.5	eval-auc:0.5
# Stopping. Best iteration:
# [0]	train-auc:0.5	eval-auc:0.5
#
# Fold  2 AUC : 0.500000
# [0]	train-auc:0.5	eval-auc:0.5
# Multiple eval metrics have been passed: 'eval-auc' will be used for early stopping.
#
# Will train until eval-auc hasn't improved in 100 rounds.
# [100]	train-auc:0.5	eval-auc:0.5
# Stopping. Best iteration:
# [0]	train-auc:0.5	eval-auc:0.5
#
# Fold  3 AUC : 0.500000
# [0]	train-auc:0.5	eval-auc:0.5
# Multiple eval metrics have been passed: 'eval-auc' will be used for early stopping.
#
# Will train until eval-auc hasn't improved in 100 rounds.
# [100]	train-auc:0.5	eval-auc:0.5
# Stopping. Best iteration:
# [0]	train-auc:0.5	eval-auc:0.5
#
# Fold  4 AUC : 0.500000
# Full AUC score 0.499978
# |  10       |  0.5      |  0.4981   |  1.964    |  2.917    |  91.0     |  0.5334   |  0.6287   |  0.006209 |  0.3356   |
# [0]	train-auc:0.722347	eval-auc:0.703938
# Multiple eval metrics have been passed: 'eval-auc' will be used for early stopping.
#
# Will train until eval-auc hasn't improved in 100 rounds.
# [100]	train-auc:0.806064	eval-auc:0.740566
# [200]	train-auc:0.854459	eval-auc:0.74323
# [300]	train-auc:0.889754	eval-auc:0.7431
# Stopping. Best iteration:
# [255]	train-auc:0.875897	eval-auc:0.744427
#
# Fold  1 AUC : 0.744427
# [0]	train-auc:0.726439	eval-auc:0.705603
# Multiple eval metrics have been passed: 'eval-auc' will be used for early stopping.
#
# Will train until eval-auc hasn't improved in 100 rounds.
# [100]	train-auc:0.808794	eval-auc:0.739805
# [200]	train-auc:0.856542	eval-auc:0.741201
# Stopping. Best iteration:
# [163]	train-auc:0.839903	eval-auc:0.741944
#
# Fold  2 AUC : 0.741944
# [0]	train-auc:0.731414	eval-auc:0.693551
# Multiple eval metrics have been passed: 'eval-auc' will be used for early stopping.
#
# Will train until eval-auc hasn't improved in 100 rounds.
# [100]	train-auc:0.812634	eval-auc:0.725523
# [200]	train-auc:0.860061	eval-auc:0.728516
# Stopping. Best iteration:
# [187]	train-auc:0.854276	eval-auc:0.728666
#
# Fold  3 AUC : 0.728666
# [0]	train-auc:0.727191	eval-auc:0.685073
# Multiple eval metrics have been passed: 'eval-auc' will be used for early stopping.
#
# Will train until eval-auc hasn't improved in 100 rounds.
# [100]	train-auc:0.809824	eval-auc:0.737209
# [200]	train-auc:0.857264	eval-auc:0.737192
# [300]	train-auc:0.89275	eval-auc:0.736863
# Stopping. Best iteration:
# [225]	train-auc:0.867038	eval-auc:0.737838
#
# Fold  4 AUC : 0.737838
# Full AUC score 0.738194
# |  11       |  0.7382   |  0.4371   |  1.0      |  6.0      |  100.0    |  0.2      |  0.2      |  1.0      |  0.9398   |
# [0]	train-auc:0.732575	eval-auc:0.699678
# Multiple eval metrics have been passed: 'eval-auc' will be used for early stopping.
#
# Will train until eval-auc hasn't improved in 100 rounds.
# [100]	train-auc:0.817668	eval-auc:0.745575
# [200]	train-auc:0.868478	eval-auc:0.748875
# [300]	train-auc:0.907321	eval-auc:0.748898
# Stopping. Best iteration:
# [225]	train-auc:0.879611	eval-auc:0.75056
#
# Fold  1 AUC : 0.750559
# [0]	train-auc:0.730719	eval-auc:0.710767
# Multiple eval metrics have been passed: 'eval-auc' will be used for early stopping.
#
# Will train until eval-auc hasn't improved in 100 rounds.
# [100]	train-auc:0.823538	eval-auc:0.745494
# Stopping. Best iteration:
# [96]	train-auc:0.82201	eval-auc:0.745714
#
# Fold  2 AUC : 0.745714
# [0]	train-auc:0.737584	eval-auc:0.684985
# Multiple eval metrics have been passed: 'eval-auc' will be used for early stopping.
#
# Will train until eval-auc hasn't improved in 100 rounds.
# [100]	train-auc:0.826104	eval-auc:0.723955
# [200]	train-auc:0.877237	eval-auc:0.729258
# [300]	train-auc:0.909787	eval-auc:0.728596
# Stopping. Best iteration:
# [224]	train-auc:0.885356	eval-auc:0.729545
#
# Fold  3 AUC : 0.729545
# [0]	train-auc:0.730902	eval-auc:0.686024
# Multiple eval metrics have been passed: 'eval-auc' will be used for early stopping.
#
# Will train until eval-auc hasn't improved in 100 rounds.
# [100]	train-auc:0.820673	eval-auc:0.737477
# [200]	train-auc:0.872992	eval-auc:0.737685
# Stopping. Best iteration:
# [193]	train-auc:0.869967	eval-auc:0.738141
#
# Fold  4 AUC : 0.738141
# Full AUC score 0.740555
# |  12       |  0.7406   |  1.0      |  2.243    |  6.0      |  80.44    |  0.2      |  0.3889   |  1.0      |  0.9456   |
# [0]	train-auc:0.731816	eval-auc:0.712418
# Multiple eval metrics have been passed: 'eval-auc' will be used for early stopping.
#
# Will train until eval-auc hasn't improved in 100 rounds.
# [100]	train-auc:0.819212	eval-auc:0.74493
# [200]	train-auc:0.834594	eval-auc:0.747203
# Stopping. Best iteration:
# [126]	train-auc:0.834563	eval-auc:0.747312
#
# Fold  1 AUC : 0.747312
# [0]	train-auc:0.726028	eval-auc:0.715045
# Multiple eval metrics have been passed: 'eval-auc' will be used for early stopping.
#
# Will train until eval-auc hasn't improved in 100 rounds.
# [100]	train-auc:0.824025	eval-auc:0.742347
# Stopping. Best iteration:
# [91]	train-auc:0.818793	eval-auc:0.74264
#
# Fold  2 AUC : 0.742640
# [0]	train-auc:0.741044	eval-auc:0.683555
# Multiple eval metrics have been passed: 'eval-auc' will be used for early stopping.
#
# Will train until eval-auc hasn't improved in 100 rounds.
# [100]	train-auc:0.827741	eval-auc:0.72427
# [200]	train-auc:0.84956	eval-auc:0.724441
# Stopping. Best iteration:
# [119]	train-auc:0.838683	eval-auc:0.72469
#
# Fold  3 AUC : 0.724690
# [0]	train-auc:0.729911	eval-auc:0.708863
# Multiple eval metrics have been passed: 'eval-auc' will be used for early stopping.
#
# Will train until eval-auc hasn't improved in 100 rounds.
# [100]	train-auc:0.821003	eval-auc:0.738272
# Stopping. Best iteration:
# [76]	train-auc:0.804898	eval-auc:0.739172
#
# Fold  4 AUC : 0.739172
# Full AUC score 0.737964
# |  13       |  0.738    |  1.0      |  9.527    |  6.0      |  71.08    |  1.0      |  1.0      |  1.0      |  1.0      |
# [0]	train-auc:0.731047	eval-auc:0.694113
# Multiple eval metrics have been passed: 'eval-auc' will be used for early stopping.
#
# Will train until eval-auc hasn't improved in 100 rounds.
# [100]	train-auc:0.898896	eval-auc:0.737255
# [200]	train-auc:0.965604	eval-auc:0.73752
# Stopping. Best iteration:
# [169]	train-auc:0.951569	eval-auc:0.73858
# Fold  1 AUC : 0.738580
# [0]	train-auc:0.732806	eval-auc:0.70334
# Multiple eval metrics have been passed: 'eval-auc' will be used for early stopping.
#
# Will train until eval-auc hasn't improved in 100 rounds.
# [100]	train-auc:0.89905	eval-auc:0.737359
# Stopping. Best iteration:
# [49]	train-auc:0.839044	eval-auc:0.739649
#
# Fold  2 AUC : 0.739649
# [0]	train-auc:0.747274	eval-auc:0.689813
# Multiple eval metrics have been passed: 'eval-auc' will be used for early stopping.
#
# Will train until eval-auc hasn't improved in 100 rounds.
# [100]	train-auc:0.890649	eval-auc:0.724633
# [200]	train-auc:0.958383	eval-auc:0.726123
# Stopping. Best iteration:
# [145]	train-auc:0.92962	eval-auc:0.726741
#
# Fold  3 AUC : 0.726741
# [0]	train-auc:0.725273	eval-auc:0.69684
# Multiple eval metrics have been passed: 'eval-auc' will be used for early stopping.
#
# Will train until eval-auc hasn't improved in 100 rounds.
# [100]	train-auc:0.89528	eval-auc:0.735387
# Stopping. Best iteration:
# [63]	train-auc:0.857798	eval-auc:0.738343
#
# Fold  4 AUC : 0.738343
# Full AUC score 0.733960
# |  14       |  0.734    |  1.0      |  1.0      |  6.0      |  10.0     |  0.2      |  0.2      |  1.0      |  1.0      |
# [0]	train-auc:0.72632	eval-auc:0.709066
# Multiple eval metrics have been passed: 'eval-auc' will be used for early stopping.
#
# Will train until eval-auc hasn't improved in 100 rounds.
# [100]	train-auc:0.856857	eval-auc:0.744254
# [200]	train-auc:0.92634	eval-auc:0.74314
# Stopping. Best iteration:
# [107]	train-auc:0.865121	eval-auc:0.745092
#
# Fold  1 AUC : 0.745092
# [0]	train-auc:0.727215	eval-auc:0.71
# Multiple eval metrics have been passed: 'eval-auc' will be used for early stopping.
#
# Will train until eval-auc hasn't improved in 100 rounds.
# [100]	train-auc:0.859047	eval-auc:0.74489
# [200]	train-auc:0.927585	eval-auc:0.744939
# Stopping. Best iteration:
# [148]	train-auc:0.896786	eval-auc:0.746535
#
# Fold  2 AUC : 0.746535
# [0]	train-auc:0.747157	eval-auc:0.684245
# Multiple eval metrics have been passed: 'eval-auc' will be used for early stopping.
#
# Will train until eval-auc hasn't improved in 100 rounds.
# [100]	train-auc:0.856147	eval-auc:0.726109
# [200]	train-auc:0.916956	eval-auc:0.725803
# Stopping. Best iteration:
# [132]	train-auc:0.879	eval-auc:0.726838
#
# Fold  3 AUC : 0.726838
# [0]	train-auc:0.730498	eval-auc:0.692839
# Multiple eval metrics have been passed: 'eval-auc' will be used for early stopping.
#
# Will train until eval-auc hasn't improved in 100 rounds.
# [100]	train-auc:0.860114	eval-auc:0.742195
# [200]	train-auc:0.918788	eval-auc:0.74064
# Stopping. Best iteration:
# [121]	train-auc:0.87613	eval-auc:0.742579
#
# Fold  4 AUC : 0.742579
# Full AUC score 0.740042
# |  15       |  0.74     |  1.0      |  1.0      |  6.0      |  30.99    |  0.2      |  0.2      |  1.0      |  1.0      |
# [0]	train-auc:0.73402	eval-auc:0.712539
# Multiple eval metrics have been passed: 'eval-auc' will be used for early stopping.
#
# Will train until eval-auc hasn't improved in 100 rounds.
# [100]	train-auc:0.833689	eval-auc:0.747104
# [200]	train-auc:0.890799	eval-auc:0.748912
# Stopping. Best iteration:
# [193]	train-auc:0.888196	eval-auc:0.748986
#
# Fold  1 AUC : 0.748986
# [0]	train-auc:0.729721	eval-auc:0.714971
# Multiple eval metrics have been passed: 'eval-auc' will be used for early stopping.
#
# Will train until eval-auc hasn't improved in 100 rounds.
# [100]	train-auc:0.837202	eval-auc:0.743525
# [200]	train-auc:0.894935	eval-auc:0.744027
# Stopping. Best iteration:
# [185]	train-auc:0.888924	eval-auc:0.744493
#
# Fold  2 AUC : 0.744493
# [0]	train-auc:0.740749	eval-auc:0.690888
# Multiple eval metrics have been passed: 'eval-auc' will be used for early stopping.
#
# Will train until eval-auc hasn't improved in 100 rounds.
# [100]	train-auc:0.841626	eval-auc:0.725102
# [200]	train-auc:0.892827	eval-auc:0.726037
# Stopping. Best iteration:
# [179]	train-auc:0.884333	eval-auc:0.727449
#
# Fold  3 AUC : 0.727449
# [0]	train-auc:0.730733	eval-auc:0.705296
# Multiple eval metrics have been passed: 'eval-auc' will be used for early stopping.
#
# Will train until eval-auc hasn't improved in 100 rounds.
# [100]	train-auc:0.84024	eval-auc:0.740111
# [200]	train-auc:0.895084	eval-auc:0.739322
# Stopping. Best iteration:
# [105]	train-auc:0.842952	eval-auc:0.740711
#
# Fold  4 AUC : 0.740711
# Full AUC score 0.740009
# |  16       |  0.74     |  1.0      |  1.0      |  6.0      |  56.6     |  0.2      |  1.0      |  1.0      |  1.0      |
# [0]	train-auc:0.639564	eval-auc:0.633182
# Multiple eval metrics have been passed: 'eval-auc' will be used for early stopping.
#
# Will train until eval-auc hasn't improved in 100 rounds.
# [100]	train-auc:0.750431	eval-auc:0.734362
# [200]	train-auc:0.767594	eval-auc:0.73946
# [300]	train-auc:0.777334	eval-auc:0.740957
# [400]	train-auc:0.782377	eval-auc:0.741788
# [500]	train-auc:0.785234	eval-auc:0.742508
# Stopping. Best iteration:
# [487]	train-auc:0.784894	eval-auc:0.742634
#
# Fold  1 AUC : 0.742634
# [0]	train-auc:0.640617	eval-auc:0.640176
# Multiple eval metrics have been passed: 'eval-auc' will be used for early stopping.
#
# Will train until eval-auc hasn't improved in 100 rounds.
# [100]	train-auc:0.74915	eval-auc:0.735232
# [200]	train-auc:0.769628	eval-auc:0.741477
# [300]	train-auc:0.778863	eval-auc:0.744017
# [400]	train-auc:0.784485	eval-auc:0.744368
# [500]	train-auc:0.786084	eval-auc:0.744525
# Stopping. Best iteration:
# [424]	train-auc:0.785271	eval-auc:0.744728
#
# Fold  2 AUC : 0.744728
# [0]	train-auc:0.651138	eval-auc:0.642788
# Multiple eval metrics have been passed: 'eval-auc' will be used for early stopping.
#
# Will train until eval-auc hasn't improved in 100 rounds.
# [100]	train-auc:0.753916	eval-auc:0.715918
# [200]	train-auc:0.771712	eval-auc:0.724152
# [300]	train-auc:0.778887	eval-auc:0.726342
# [400]	train-auc:0.781649	eval-auc:0.72663
# Stopping. Best iteration:
# [355]	train-auc:0.780902	eval-auc:0.726842
#
# Fold  3 AUC : 0.726842
# [0]	train-auc:0.639675	eval-auc:0.640155
# Multiple eval metrics have been passed: 'eval-auc' will be used for early stopping.
#
# Will train until eval-auc hasn't improved in 100 rounds.
# [100]	train-auc:0.750538	eval-auc:0.731733
# [200]	train-auc:0.76971	eval-auc:0.736692
# [300]	train-auc:0.777594	eval-auc:0.737568
# [400]	train-auc:0.782634	eval-auc:0.738324
# [500]	train-auc:0.785108	eval-auc:0.738692
# [600]	train-auc:0.788503	eval-auc:0.738881
# [700]	train-auc:0.790803	eval-auc:0.73923
# Stopping. Best iteration:
# [692]	train-auc:0.790721	eval-auc:0.739303
#
# Fold  4 AUC : 0.739303
# Full AUC score 0.738272
# |  17       |  0.7383   |  0.05     |  10.0     |  2.0      |  20.14    |  1.0      |  1.0      |  1.0      |  1.0      |
# [0]	train-auc:0.5	eval-auc:0.5
# Multiple eval metrics have been passed: 'eval-auc' will be used for early stopping.
#
# Will train until eval-auc hasn't improved in 100 rounds.
# [100]	train-auc:0.5	eval-auc:0.5
# Stopping. Best iteration:
# [0]	train-auc:0.5	eval-auc:0.5
#
# Fold  1 AUC : 0.500000
# [0]	train-auc:0.5	eval-auc:0.5
# Multiple eval metrics have been passed: 'eval-auc' will be used for early stopping.
#
# Will train until eval-auc hasn't improved in 100 rounds.
# [100]	train-auc:0.5	eval-auc:0.5
# Stopping. Best iteration:
# [0]	train-auc:0.5	eval-auc:0.5
#
# Fold  2 AUC : 0.500000
# [0]	train-auc:0.5	eval-auc:0.5
# Multiple eval metrics have been passed: 'eval-auc' will be used for early stopping.
#
# Will train until eval-auc hasn't improved in 100 rounds.
# [100]	train-auc:0.5	eval-auc:0.5
# Stopping. Best iteration:
# [0]	train-auc:0.5	eval-auc:0.5
#
# Fold  3 AUC : 0.500000
# [0]	train-auc:0.5	eval-auc:0.5
# Multiple eval metrics have been passed: 'eval-auc' will be used for early stopping.
#
# Will train until eval-auc hasn't improved in 100 rounds.
# [100]	train-auc:0.5	eval-auc:0.5
# Stopping. Best iteration:
# [0]	train-auc:0.5	eval-auc:0.5
#
# Fold  4 AUC : 0.500000
# Full AUC score 0.500000
# |  18       |  0.5      |  1.0      |  10.0     |  6.0      |  10.0     |  0.2      |  0.2      |  0.0      |  0.05     |
# [0]	train-auc:0.639564	eval-auc:0.633182
# Multiple eval metrics have been passed: 'eval-auc' will be used for early stopping.
#
# Will train until eval-auc hasn't improved in 100 rounds.
# [100]	train-auc:0.751276	eval-auc:0.734808
# [200]	train-auc:0.771048	eval-auc:0.739531
# [300]	train-auc:0.789389	eval-auc:0.742457
# [400]	train-auc:0.804552	eval-auc:0.742764
# [500]	train-auc:0.817719	eval-auc:0.743393
# Stopping. Best iteration:
# [479]	train-auc:0.815196	eval-auc:0.744142
#
# Fold  1 AUC : 0.744142
# [0]	train-auc:0.640617	eval-auc:0.640176
# Multiple eval metrics have been passed: 'eval-auc' will be used for early stopping.
#
# Will train until eval-auc hasn't improved in 100 rounds.
# [100]	train-auc:0.749766	eval-auc:0.734769
# [200]	train-auc:0.772473	eval-auc:0.740978
# [300]	train-auc:0.790087	eval-auc:0.744061
# [400]	train-auc:0.805448	eval-auc:0.744417
# [500]	train-auc:0.818566	eval-auc:0.745504
# [600]	train-auc:0.829918	eval-auc:0.746274
# [700]	train-auc:0.841764	eval-auc:0.746041
# Stopping. Best iteration:
# [608]	train-auc:0.831025	eval-auc:0.746519
#
# Fold  2 AUC : 0.746519
# [0]	train-auc:0.651138	eval-auc:0.642788
# Multiple eval metrics have been passed: 'eval-auc' will be used for early stopping.
#
# Will train until eval-auc hasn't improved in 100 rounds.
# [100]	train-auc:0.753912	eval-auc:0.716124
# [200]	train-auc:0.773984	eval-auc:0.724642
# [300]	train-auc:0.789581	eval-auc:0.727885
# [400]	train-auc:0.8028	eval-auc:0.730236
# [500]	train-auc:0.815271	eval-auc:0.73148
# [600]	train-auc:0.826386	eval-auc:0.73215
# [700]	train-auc:0.83714	eval-auc:0.732288
# Stopping. Best iteration:
# [614]	train-auc:0.827787	eval-auc:0.732462
#
# Fold  3 AUC : 0.732462
# [0]	train-auc:0.639675	eval-auc:0.640155
# Multiple eval metrics have been passed: 'eval-auc' will be used for early stopping.
#
# Will train until eval-auc hasn't improved in 100 rounds.
# [100]	train-auc:0.750867	eval-auc:0.731124
# [200]	train-auc:0.771974	eval-auc:0.735952
# [300]	train-auc:0.78968	eval-auc:0.737827
# [400]	train-auc:0.803862	eval-auc:0.739462
# [500]	train-auc:0.81633	eval-auc:0.739991
# Stopping. Best iteration:
# [459]	train-auc:0.811834	eval-auc:0.740236
#
# Fold  4 AUC : 0.740236
# Full AUC score 0.740645
# |  19       |  0.7406   |  0.05     |  1.0      |  2.0      |  20.44    |  1.0      |  1.0      |  1.0      |  1.0      |
# [0]	train-auc:0.639564	eval-auc:0.633182
# Multiple eval metrics have been passed: 'eval-auc' will be used for early stopping.
#
# Will train until eval-auc hasn't improved in 100 rounds.
# [100]	train-auc:0.749996	eval-auc:0.734525
# [200]	train-auc:0.766632	eval-auc:0.739455
# [300]	train-auc:0.776379	eval-auc:0.741265
# [400]	train-auc:0.780816	eval-auc:0.742344
# [500]	train-auc:0.783067	eval-auc:0.742878
# [600]	train-auc:0.784464	eval-auc:0.743123
# [700]	train-auc:0.78654	eval-auc:0.743679
# [800]	train-auc:0.787576	eval-auc:0.743775
# [900]	train-auc:0.788866	eval-auc:0.743988
# [1000]	train-auc:0.790709	eval-auc:0.743864
# Stopping. Best iteration:
# [919]	train-auc:0.789265	eval-auc:0.744173
#
# Fold  1 AUC : 0.744173
# [0]	train-auc:0.640542	eval-auc:0.639953
# Multiple eval metrics have been passed: 'eval-auc' will be used for early stopping.
#
# Will train until eval-auc hasn't improved in 100 rounds.
# [100]	train-auc:0.748339	eval-auc:0.735051
# [200]	train-auc:0.767455	eval-auc:0.740573
# [300]	train-auc:0.777134	eval-auc:0.742751
# [400]	train-auc:0.782248	eval-auc:0.743448
# [500]	train-auc:0.784442	eval-auc:0.74358
# Stopping. Best iteration:
# [424]	train-auc:0.783176	eval-auc:0.743703
#
# Fold  2 AUC : 0.743703
# [0]	train-auc:0.673213	eval-auc:0.65102
# Multiple eval metrics have been passed: 'eval-auc' will be used for early stopping.
#
# Will train until eval-auc hasn't improved in 100 rounds.
# [100]	train-auc:0.754169	eval-auc:0.717482
# [200]	train-auc:0.77007	eval-auc:0.725723
# [300]	train-auc:0.777502	eval-auc:0.727668
# [400]	train-auc:0.780421	eval-auc:0.72766
# Stopping. Best iteration:
# [347]	train-auc:0.779764	eval-auc:0.728067
#
# Fold  3 AUC : 0.728067
# [0]	train-auc:0.639905	eval-auc:0.642424
# Multiple eval metrics have been passed: 'eval-auc' will be used for early stopping.
#
# Will train until eval-auc hasn't improved in 100 rounds.
# [100]	train-auc:0.750383	eval-auc:0.731759
# [200]	train-auc:0.768054	eval-auc:0.737401
# [300]	train-auc:0.775417	eval-auc:0.737851
# Stopping. Best iteration:
# [292]	train-auc:0.775066	eval-auc:0.738076
#
# Fold  4 AUC : 0.738076
# Full AUC score 0.738455
# |  20       |  0.7385   |  0.05     |  10.0     |  2.0      |  31.47    |  1.0      |  1.0      |  1.0      |  1.0      |
# [0]	train-auc:0.727801	eval-auc:0.703833
# Multiple eval metrics have been passed: 'eval-auc' will be used for early stopping.
#
# Will train until eval-auc hasn't improved in 100 rounds.
# [100]	train-auc:0.844759	eval-auc:0.742218
# [200]	train-auc:0.864557	eval-auc:0.745182
# Stopping. Best iteration:
# [127]	train-auc:0.864132	eval-auc:0.745213
#
# Fold  1 AUC : 0.745213
# [0]	train-auc:0.72933	eval-auc:0.709863
# Multiple eval metrics have been passed: 'eval-auc' will be used for early stopping.
#
# Will train until eval-auc hasn't improved in 100 rounds.
# [100]	train-auc:0.850054	eval-auc:0.745583
# [200]	train-auc:0.868999	eval-auc:0.745087
# Stopping. Best iteration:
# [101]	train-auc:0.850481	eval-auc:0.745757
#
# Fold  2 AUC : 0.745757
# [0]	train-auc:0.745227	eval-auc:0.686769
# Multiple eval metrics have been passed: 'eval-auc' will be used for early stopping.
#
# Will train until eval-auc hasn't improved in 100 rounds.
# [100]	train-auc:0.846043	eval-auc:0.727595
# [200]	train-auc:0.854279	eval-auc:0.728096
# Stopping. Best iteration:
# [163]	train-auc:0.854279	eval-auc:0.728096
#
# Fold  3 AUC : 0.728096
# [0]	train-auc:0.725043	eval-auc:0.694134
# Multiple eval metrics have been passed: 'eval-auc' will be used for early stopping.
#
# Will train until eval-auc hasn't improved in 100 rounds.
# [100]	train-auc:0.842654	eval-auc:0.739613
# [200]	train-auc:0.86195	eval-auc:0.737941
# Stopping. Best iteration:
# [103]	train-auc:0.844653	eval-auc:0.739848
#
# Fold  4 AUC : 0.739848
# Full AUC score 0.739476
# |  21       |  0.7395   |  1.0      |  10.0     |  6.0      |  26.06    |  0.2      |  0.2      |  1.0      |  1.0      |
# [0]	train-auc:0.640749	eval-auc:0.63879
# Multiple eval metrics have been passed: 'eval-auc' will be used for early stopping.
#
# Will train until eval-auc hasn't improved in 100 rounds.
# [100]	train-auc:0.756607	eval-auc:0.73906
# [200]	train-auc:0.778319	eval-auc:0.742853
# [300]	train-auc:0.797209	eval-auc:0.745272
# [400]	train-auc:0.812476	eval-auc:0.745372
# Stopping. Best iteration:
# [391]	train-auc:0.811283	eval-auc:0.745602
#
# Fold  1 AUC : 0.745602
# [0]	train-auc:0.640799	eval-auc:0.636976
# Multiple eval metrics have been passed: 'eval-auc' will be used for early stopping.
#
# Will train until eval-auc hasn't improved in 100 rounds.
# [100]	train-auc:0.755194	eval-auc:0.739773
# [200]	train-auc:0.777468	eval-auc:0.742371
# [300]	train-auc:0.796623	eval-auc:0.745401
# [400]	train-auc:0.812294	eval-auc:0.745182
# [500]	train-auc:0.826442	eval-auc:0.746725
# Stopping. Best iteration:
# [478]	train-auc:0.823715	eval-auc:0.746924
#
# Fold  2 AUC : 0.746924
# [0]	train-auc:0.679825	eval-auc:0.664391
# Multiple eval metrics have been passed: 'eval-auc' will be used for early stopping.
#
# Will train until eval-auc hasn't improved in 100 rounds.
# [100]	train-auc:0.760788	eval-auc:0.722084
# [200]	train-auc:0.780943	eval-auc:0.726398
# [300]	train-auc:0.797274	eval-auc:0.728647
# [400]	train-auc:0.811872	eval-auc:0.731062
# [500]	train-auc:0.82613	eval-auc:0.732923
# [600]	train-auc:0.838301	eval-auc:0.731459
# Stopping. Best iteration:
# [526]	train-auc:0.828898	eval-auc:0.733066
#
# Fold  3 AUC : 0.733066
# [0]	train-auc:0.674614	eval-auc:0.663223
# Multiple eval metrics have been passed: 'eval-auc' will be used for early stopping.
#
# Will train until eval-auc hasn't improved in 100 rounds.
# [100]	train-auc:0.75686	eval-auc:0.734449
# [200]	train-auc:0.777026	eval-auc:0.737739
# [300]	train-auc:0.796465	eval-auc:0.740454
# [400]	train-auc:0.813154	eval-auc:0.741745
# [500]	train-auc:0.827074	eval-auc:0.741629
# Stopping. Best iteration:
# [462]	train-auc:0.821757	eval-auc:0.742714
# Fold  4 AUC : 0.742714
# Full AUC score 0.741852
# |  22       |  0.7419   |  1.0      |  1.0      |  2.0      |  44.04    |  0.2      |  0.2      |  1.0      |  1.0      |
# [0]	train-auc:0.723509	eval-auc:0.703865
# Multiple eval metrics have been passed: 'eval-auc' will be used for early stopping.
#
# Will train until eval-auc hasn't improved in 100 rounds.
# [100]	train-auc:0.799287	eval-auc:0.743907
# [200]	train-auc:0.833394	eval-auc:0.746957
# [300]	train-auc:0.853183	eval-auc:0.748871
# Stopping. Best iteration:
# [276]	train-auc:0.848975	eval-auc:0.749536
#
# Fold  1 AUC : 0.749536
# [0]	train-auc:0.714663	eval-auc:0.710751
# Multiple eval metrics have been passed: 'eval-auc' will be used for early stopping.
#
# Will train until eval-auc hasn't improved in 100 rounds.
# [100]	train-auc:0.804074	eval-auc:0.741098
# [200]	train-auc:0.835638	eval-auc:0.74274
# [300]	train-auc:0.852958	eval-auc:0.742985
# [400]	train-auc:0.862806	eval-auc:0.742699
# Stopping. Best iteration:
# [346]	train-auc:0.857623	eval-auc:0.743556
#
# Fold  2 AUC : 0.743556
# [0]	train-auc:0.722946	eval-auc:0.691062
# Multiple eval metrics have been passed: 'eval-auc' will be used for early stopping.
#
# Will train until eval-auc hasn't improved in 100 rounds.
# [100]	train-auc:0.802049	eval-auc:0.724599
# [200]	train-auc:0.837235	eval-auc:0.729381
# [300]	train-auc:0.853256	eval-auc:0.730628
# [400]	train-auc:0.866074	eval-auc:0.731585
# [500]	train-auc:0.875063	eval-auc:0.730555
# Stopping. Best iteration:
# [410]	train-auc:0.867395	eval-auc:0.731696
#
# Fold  3 AUC : 0.731696
# [0]	train-auc:0.719782	eval-auc:0.70738
# Multiple eval metrics have been passed: 'eval-auc' will be used for early stopping.
#
# Will train until eval-auc hasn't improved in 100 rounds.
# [100]	train-auc:0.803359	eval-auc:0.735346
# [200]	train-auc:0.836758	eval-auc:0.735831
# Stopping. Best iteration:
# [158]	train-auc:0.82558	eval-auc:0.736704
#
# Fold  4 AUC : 0.736704
# Full AUC score 0.740045
# |  23       |  0.74     |  0.05     |  10.0     |  6.0      |  42.39    |  0.2      |  0.2      |  1.0      |  1.0      |
# [0]	train-auc:0.5	eval-auc:0.5
# Multiple eval metrics have been passed: 'eval-auc' will be used for early stopping.
#
# Will train until eval-auc hasn't improved in 100 rounds.
# [100]	train-auc:0.5	eval-auc:0.5
# Stopping. Best iteration:
# [0]	train-auc:0.5	eval-auc:0.5
#
# Fold  1 AUC : 0.500000
# [0]	train-auc:0.5	eval-auc:0.5
# Multiple eval metrics have been passed: 'eval-auc' will be used for early stopping.
#
# Will train until eval-auc hasn't improved in 100 rounds.
# [100]	train-auc:0.5	eval-auc:0.5
# Stopping. Best iteration:
# [0]	train-auc:0.5	eval-auc:0.5
#
# Fold  2 AUC : 0.500000
# [0]	train-auc:0.5	eval-auc:0.5
# Multiple eval metrics have been passed: 'eval-auc' will be used for early stopping.
#
# Will train until eval-auc hasn't improved in 100 rounds.
# [100]	train-auc:0.5	eval-auc:0.5
# Stopping. Best iteration:
# [0]	train-auc:0.5	eval-auc:0.5
#
# Fold  3 AUC : 0.500000
# [0]	train-auc:0.5	eval-auc:0.5
# Multiple eval metrics have been passed: 'eval-auc' will be used for early stopping.
#
# Will train until eval-auc hasn't improved in 100 rounds.
# [100]	train-auc:0.5	eval-auc:0.5
# Stopping. Best iteration:
# [0]	train-auc:0.5	eval-auc:0.5
#
# Fold  4 AUC : 0.500000
# Full AUC score 0.500000
# |  24       |  0.5      |  0.05     |  5.935    |  6.0      |  77.26    |  1.0      |  1.0      |  1.0      |  0.05     |
# [0]	train-auc:0.5	eval-auc:0.5
# Multiple eval metrics have been passed: 'eval-auc' will be used for early stopping.
#
# Will train until eval-auc hasn't improved in 100 rounds.
# [100]	train-auc:0.5	eval-auc:0.5
# Stopping. Best iteration:
# [0]	train-auc:0.5	eval-auc:0.5
#
# Fold  1 AUC : 0.500000
# [0]	train-auc:0.5	eval-auc:0.5
# Multiple eval metrics have been passed: 'eval-auc' will be used for early stopping.
#
# Will train until eval-auc hasn't improved in 100 rounds.
# [100]	train-auc:0.5	eval-auc:0.5
# Stopping. Best iteration:
# [0]	train-auc:0.5	eval-auc:0.5
#
# Fold  2 AUC : 0.500000
# [0]	train-auc:0.5	eval-auc:0.5
# Multiple eval metrics have been passed: 'eval-auc' will be used for early stopping.
#
# Will train until eval-auc hasn't improved in 100 rounds.
# [100]	train-auc:0.5	eval-auc:0.5
# Stopping. Best iteration:
# [0]	train-auc:0.5	eval-auc:0.5
#
# Fold  3 AUC : 0.500000
# [0]	train-auc:0.5	eval-auc:0.5
# Multiple eval metrics have been passed: 'eval-auc' will be used for early stopping.
#
# Will train until eval-auc hasn't improved in 100 rounds.
# [100]	train-auc:0.5	eval-auc:0.5
# Stopping. Best iteration:
# [0]	train-auc:0.5	eval-auc:0.5
#
# Fold  4 AUC : 0.500000
# Full AUC score 0.500000
# |  25       |  0.5      |  1.0      |  10.0     |  2.688    |  80.94    |  0.2      |  0.2      |  0.0      |  1.0      |
# [0]	train-auc:0.701622	eval-auc:0.682417
# Multiple eval metrics have been passed: 'eval-auc' will be used for early stopping.
#
# Will train until eval-auc hasn't improved in 100 rounds.
# [100]	train-auc:0.777916	eval-auc:0.738157
# [200]	train-auc:0.798425	eval-auc:0.740191
# Stopping. Best iteration:
# [160]	train-auc:0.798425	eval-auc:0.740191
#
# Fold  1 AUC : 0.740191
# [0]	train-auc:0.698679	eval-auc:0.679792
# Multiple eval metrics have been passed: 'eval-auc' will be used for early stopping.
#
# Will train until eval-auc hasn't improved in 100 rounds.
# [100]	train-auc:0.78062	eval-auc:0.739377
# [200]	train-auc:0.799174	eval-auc:0.740719
# Stopping. Best iteration:
# [123]	train-auc:0.788806	eval-auc:0.741344
#
# Fold  2 AUC : 0.741344
# [0]	train-auc:0.709398	eval-auc:0.680515
# Multiple eval metrics have been passed: 'eval-auc' will be used for early stopping.
#
# Will train until eval-auc hasn't improved in 100 rounds.
# [100]	train-auc:0.783127	eval-auc:0.718533
# [200]	train-auc:0.805371	eval-auc:0.722579
# Stopping. Best iteration:
# [167]	train-auc:0.805371	eval-auc:0.722579
#
# Fold  3 AUC : 0.722579
# [0]	train-auc:0.695762	eval-auc:0.689525
# Multiple eval metrics have been passed: 'eval-auc' will be used for early stopping.
#
# Will train until eval-auc hasn't improved in 100 rounds.
# [100]	train-auc:0.777262	eval-auc:0.734788
# [200]	train-auc:0.786534	eval-auc:0.735593
# Stopping. Best iteration:
# [111]	train-auc:0.781712	eval-auc:0.736395
#
# Fold  4 AUC : 0.736395
# Full AUC score 0.734651
# |  26       |  0.7347   |  1.0      |  6.279    |  6.0      |  83.71    |  0.6592   |  0.7556   |  0.4295   |  1.0      |
# [0]	train-auc:0.732166	eval-auc:0.707598
# Multiple eval metrics have been passed: 'eval-auc' will be used for early stopping.
#
# Will train until eval-auc hasn't improved in 100 rounds.
# [100]	train-auc:0.819532	eval-auc:0.744244
# [200]	train-auc:0.826719	eval-auc:0.743979
# Stopping. Best iteration:
# [104]	train-auc:0.821743	eval-auc:0.744391
#
# Fold  1 AUC : 0.744391
# [0]	train-auc:0.726853	eval-auc:0.71315
# Multiple eval metrics have been passed: 'eval-auc' will be used for early stopping.
#
# Will train until eval-auc hasn't improved in 100 rounds.
# [100]	train-auc:0.819398	eval-auc:0.743741
# [200]	train-auc:0.83203	eval-auc:0.74386
# Stopping. Best iteration:
# [122]	train-auc:0.83203	eval-auc:0.74386
#
# Fold  2 AUC : 0.743860
# [0]	train-auc:0.738932	eval-auc:0.68669
# Multiple eval metrics have been passed: 'eval-auc' will be used for early stopping.
#
# Will train until eval-auc hasn't improved in 100 rounds.
# [100]	train-auc:0.82467	eval-auc:0.725603
# [200]	train-auc:0.846475	eval-auc:0.725661
# Stopping. Best iteration:
# [127]	train-auc:0.837133	eval-auc:0.72665
#
# Fold  3 AUC : 0.726650
# [0]	train-auc:0.723522	eval-auc:0.698042
# Multiple eval metrics have been passed: 'eval-auc' will be used for early stopping.
#
# Will train until eval-auc hasn't improved in 100 rounds.
# [100]	train-auc:0.819698	eval-auc:0.741119
# Stopping. Best iteration:
# [94]	train-auc:0.815591	eval-auc:0.741748
#
# Fold  4 AUC : 0.741748
# Full AUC score 0.738811
# |  27       |  0.7388   |  1.0      |  10.0     |  6.0      |  65.41    |  0.2      |  0.8155   |  0.9959   |  1.0      |
# [0]	train-auc:0.642314	eval-auc:0.644005
# Multiple eval metrics have been passed: 'eval-auc' will be used for early stopping.
#
# Will train until eval-auc hasn't improved in 100 rounds.
# [100]	train-auc:0.739971	eval-auc:0.728688
# [200]	train-auc:0.754023	eval-auc:0.731591
# [300]	train-auc:0.765679	eval-auc:0.733683
# [400]	train-auc:0.775716	eval-auc:0.734653
# [500]	train-auc:0.783625	eval-auc:0.736064
# [600]	train-auc:0.791182	eval-auc:0.736832
# [700]	train-auc:0.797646	eval-auc:0.737932
# [800]	train-auc:0.803704	eval-auc:0.738711
# Stopping. Best iteration:
# [796]	train-auc:0.80347	eval-auc:0.73876
#
# Fold  1 AUC : 0.738760
# [0]	train-auc:0.643153	eval-auc:0.641651
# Multiple eval metrics have been passed: 'eval-auc' will be used for early stopping.
#
# Will train until eval-auc hasn't improved in 100 rounds.
# [100]	train-auc:0.738285	eval-auc:0.731222
# [200]	train-auc:0.753705	eval-auc:0.736576
# [300]	train-auc:0.764023	eval-auc:0.735882
# Stopping. Best iteration:
# [240]	train-auc:0.757969	eval-auc:0.736669
#
# Fold  2 AUC : 0.736669
# [0]	train-auc:0.663509	eval-auc:0.640571
# Multiple eval metrics have been passed: 'eval-auc' will be used for early stopping.
#
# Will train until eval-auc hasn't improved in 100 rounds.
# [100]	train-auc:0.744206	eval-auc:0.712683
# [200]	train-auc:0.759022	eval-auc:0.716479
# [300]	train-auc:0.770214	eval-auc:0.719585
# [400]	train-auc:0.779835	eval-auc:0.721262
# [500]	train-auc:0.788	eval-auc:0.721363
# [600]	train-auc:0.795209	eval-auc:0.721916
# [700]	train-auc:0.801579	eval-auc:0.722078
# Stopping. Best iteration:
# [693]	train-auc:0.801252	eval-auc:0.722231
#
# Fold  3 AUC : 0.722231
# [0]	train-auc:0.668824	eval-auc:0.6573
# Multiple eval metrics have been passed: 'eval-auc' will be used for early stopping.
#
# Will train until eval-auc hasn't improved in 100 rounds.
# [100]	train-auc:0.738752	eval-auc:0.72565
# [200]	train-auc:0.754009	eval-auc:0.731086
# [300]	train-auc:0.766501	eval-auc:0.731273
# [400]	train-auc:0.775539	eval-auc:0.73196
# [500]	train-auc:0.783958	eval-auc:0.73294
# [600]	train-auc:0.7909	eval-auc:0.73275
# Stopping. Best iteration:
# [531]	train-auc:0.78622	eval-auc:0.733155
#
# Fold  4 AUC : 0.733155
# Full AUC score 0.732130
# |  28       |  0.7321   |  1.0      |  1.0      |  2.58     |  80.21    |  0.2      |  0.2      |  0.2019   |  1.0      |
# [0]	train-auc:0.5	eval-auc:0.5
# Multiple eval metrics have been passed: 'eval-auc' will be used for early stopping.
#
# Will train until eval-auc hasn't improved in 100 rounds.
# [100]	train-auc:0.5	eval-auc:0.5
# Stopping. Best iteration:
# [0]	train-auc:0.5	eval-auc:0.5
#
# Fold  1 AUC : 0.500000
# [0]	train-auc:0.5	eval-auc:0.5
# Multiple eval metrics have been passed: 'eval-auc' will be used for early stopping.
#
# Will train until eval-auc hasn't improved in 100 rounds.
# [100]	train-auc:0.5	eval-auc:0.5
# Stopping. Best iteration:
# [0]	train-auc:0.5	eval-auc:0.5
#
# Fold  2 AUC : 0.500000
# [0]	train-auc:0.5	eval-auc:0.5
# Multiple eval metrics have been passed: 'eval-auc' will be used for early stopping.
#
# Will train until eval-auc hasn't improved in 100 rounds.
# [100]	train-auc:0.5	eval-auc:0.5
# Stopping. Best iteration:
# [0]	train-auc:0.5	eval-auc:0.5
#
# Fold  3 AUC : 0.500000
# [0]	train-auc:0.5	eval-auc:0.5
# Multiple eval metrics have been passed: 'eval-auc' will be used for early stopping.
#
# Will train until eval-auc hasn't improved in 100 rounds.
# [100]	train-auc:0.5	eval-auc:0.5
# Stopping. Best iteration:
# [0]	train-auc:0.5	eval-auc:0.5
#
# Fold  4 AUC : 0.500000
# Full AUC score 0.500000
# |  29       |  0.5      |  1.0      |  1.0      |  6.0      |  68.45    |  0.2      |  0.2      |  0.0      |  1.0      |
# [0]	train-auc:0.672462	eval-auc:0.680625
# Multiple eval metrics have been passed: 'eval-auc' will be used for early stopping.
#
# Will train until eval-auc hasn't improved in 100 rounds.
# [100]	train-auc:0.755836	eval-auc:0.73944
# [200]	train-auc:0.775821	eval-auc:0.742407
# [300]	train-auc:0.782385	eval-auc:0.743514
# Stopping. Best iteration:
# [228]	train-auc:0.781403	eval-auc:0.743599
#
# Fold  1 AUC : 0.743599
# [0]	train-auc:0.673564	eval-auc:0.677209
# Multiple eval metrics have been passed: 'eval-auc' will be used for early stopping.
#
# Will train until eval-auc hasn't improved in 100 rounds.
# [100]	train-auc:0.753432	eval-auc:0.738415
# [200]	train-auc:0.773653	eval-auc:0.740518
# [300]	train-auc:0.780195	eval-auc:0.741002
# Stopping. Best iteration:
# [233]	train-auc:0.780195	eval-auc:0.741003
#
# Fold  2 AUC : 0.741003
# [0]	train-auc:0.679825	eval-auc:0.664391
# Multiple eval metrics have been passed: 'eval-auc' will be used for early stopping.
#
# Will train until eval-auc hasn't improved in 100 rounds.
# [100]	train-auc:0.759055	eval-auc:0.720677
# [200]	train-auc:0.777601	eval-auc:0.7266
# [300]	train-auc:0.78308	eval-auc:0.726872
# Stopping. Best iteration:
# [225]	train-auc:0.781988	eval-auc:0.726942
#
# Fold  3 AUC : 0.726942
# [0]	train-auc:0.675096	eval-auc:0.664504
# Multiple eval metrics have been passed: 'eval-auc' will be used for early stopping.
#
# Will train until eval-auc hasn't improved in 100 rounds.
# [100]	train-auc:0.755703	eval-auc:0.734179
# [200]	train-auc:0.775852	eval-auc:0.736573
# Stopping. Best iteration:
# [191]	train-auc:0.773893	eval-auc:0.737479
#
# Fold  4 AUC : 0.737479
# Full AUC score 0.737082
# |  30       |  0.7371   |  1.0      |  9.17     |  2.0      |  65.81    |  1.0      |  1.0      |  1.0      |  1.0      |
# =========================================================================================================================
# Final result: {'target': 0.7418518404111353, 'params': {'colsample_bytree': 1.0, 'gamma': 1.0, 'max_depth': 2.0, 'min_child_weight': 44.043837765163296, 'reg_alpha': 0.2, 'reg_lambda': 0.2, 'scale_pos_weight': 1.0, 'subsample': 1.0}}

# %%
from six.moves import cPickle
def get_test_result(X_test, y_test, model='xgb'):
    if model == 'xgb':
        fname=max(glob.glob('*-xgb*.dict'))
    elif model == 'lgb':
        fname=max(glob.glob('*-lgb*.dict'))
    fname= fname.encode()
    with open(fname, 'rb') as fl:
        res = cPickle.load(fl)

    res_df = pd.DataFrame(res)
    top_res = res_df['target'].argsort().iloc[-num_params:]
    num_round_index = top_res.values[::-1]
    params = res_df.loc[top_res.values[::-1]]['params']
   # subs = dict()
    for res_name, (nm_rnd, param) in enumerate(zip(num_round_index, params)):
        if model == 'xgb':
            sub = xgb_cv(X_train, X_test, y_train, **param, test_phase=True, stratify=stratify)
        elif model == 'lgb':
            sub = lgb_cv(X_train, X_test, y_train, **param, test_phase=True, stratify=stratify)
    
    if model == 'xgb':
        print(f"xgboost test set AUC: {roc_auc_score(y_test, sub)}")
        return sub
    elif model == 'lgb':
        print(f"lightgbm test set AUC: {roc_auc_score(y_test, sub)}")
        return sub

# %%
sub_xgb = get_test_result(X_test, y_test, model='xgb')
# Out:
# [0]	train-auc:0.640602	eval-auc:0.63879
# Multiple eval metrics have been passed: 'eval-auc' will be used for early stopping.
#
# Will train until eval-auc hasn't improved in 100 rounds.
# [100]	train-auc:0.756598	eval-auc:0.739187
# [200]	train-auc:0.778555	eval-auc:0.742302
# [300]	train-auc:0.79773	eval-auc:0.744532
# [400]	train-auc:0.812995	eval-auc:0.745301
# Stopping. Best iteration:
# [396]	train-auc:0.812327	eval-auc:0.745416
#
# Fold  1 AUC : 0.745416
# [0]	train-auc:0.640799	eval-auc:0.636976
# Multiple eval metrics have been passed: 'eval-auc' will be used for early stopping.
#
# Will train until eval-auc hasn't improved in 100 rounds.
# [100]	train-auc:0.755552	eval-auc:0.739603
# [200]	train-auc:0.776864	eval-auc:0.743066
# [300]	train-auc:0.795824	eval-auc:0.744526
# [400]	train-auc:0.812234	eval-auc:0.745672
# [500]	train-auc:0.825632	eval-auc:0.745764
# [600]	train-auc:0.838313	eval-auc:0.74604
# Stopping. Best iteration:
# [579]	train-auc:0.835646	eval-auc:0.746438
#
# Fold  2 AUC : 0.746438
# [0]	train-auc:0.679825	eval-auc:0.664391
# Multiple eval metrics have been passed: 'eval-auc' will be used for early stopping.
#
# Will train until eval-auc hasn't improved in 100 rounds.
# [100]	train-auc:0.760784	eval-auc:0.722087
# [200]	train-auc:0.781317	eval-auc:0.726333
# [300]	train-auc:0.797715	eval-auc:0.72868
# [400]	train-auc:0.812183	eval-auc:0.731437
# [500]	train-auc:0.825951	eval-auc:0.73115
# Stopping. Best iteration:
# [424]	train-auc:0.815357	eval-auc:0.731924
#
# Fold  3 AUC : 0.731924
# [0]	train-auc:0.674614	eval-auc:0.663223
# Multiple eval metrics have been passed: 'eval-auc' will be used for early stopping.
#
# Will train until eval-auc hasn't improved in 100 rounds.
# [100]	train-auc:0.75686	eval-auc:0.734449
# [200]	train-auc:0.777717	eval-auc:0.737111
# [300]	train-auc:0.79716	eval-auc:0.741218
# [400]	train-auc:0.812991	eval-auc:0.741257
# [500]	train-auc:0.827264	eval-auc:0.741351
# Stopping. Best iteration:
# [476]	train-auc:0.824412	eval-auc:0.742016
#
# Fold  4 AUC : 0.742016
# Full AUC score 0.741271
# xgboost test set AUC: 0.7350024252874352

# %%
sub_lgb = get_test_result(X_test, y_test, model='lgb')
# Out:
# Training until validation scores don't improve for 500 rounds.
# Early stopping, best iteration is:
# [149]	training's auc: 0.793607	valid_1's auc: 0.735233
# Fold  1 AUC : 0.735233
# Training until validation scores don't improve for 500 rounds.
# Early stopping, best iteration is:
# [148]	training's auc: 0.793273	valid_1's auc: 0.732797
# Fold  2 AUC : 0.732797
# Training until validation scores don't improve for 500 rounds.
# Early stopping, best iteration is:
# [118]	training's auc: 0.786265	valid_1's auc: 0.730245
# Fold  3 AUC : 0.730245
# Training until validation scores don't improve for 500 rounds.
# Early stopping, best iteration is:
# [190]	training's auc: 0.808311	valid_1's auc: 0.728908
# Fold  4 AUC : 0.728908
# Training until validation scores don't improve for 500 rounds.
# Early stopping, best iteration is:
# [93]	training's auc: 0.773113	valid_1's auc: 0.743349
# Fold  5 AUC : 0.743349
# Full AUC score 0.733629
# lightgbm test set AUC: 0.7289775570928088

# %%
print(f'mean combined predictions for single xgb and lgb models \
{roc_auc_score(y_test, ((sub_lgb + sub_xgb) / 2))}')
# Out:
# mean combined predictions for single xgb and lgb models 0.7340758026587321

# %% [markdown]
# ### Demo for Grab Evaluation

# %%
grab_data = get_all_data(labels, features) #just use the features files
# Out:
# processing file ../features/part-00000-e6120af0-10c2-4248-97c4-81baf4304e5c-c000.csv
# Memory usage of dataframe is 135.41 MB
# Memory usage after optimization is: 46.16 MB
# Decreased by 65.9%
# processing file ../features/part-00001-e6120af0-10c2-4248-97c4-81baf4304e5c-c000.csv
# Memory usage of dataframe is 135.42 MB
# Memory usage after optimization is: 46.16 MB
# Decreased by 65.9%
# processing file ../features/part-00002-e6120af0-10c2-4248-97c4-81baf4304e5c-c000.csv
# Memory usage of dataframe is 135.42 MB
# Memory usage after optimization is: 46.16 MB
# Decreased by 65.9%
# processing file ../features/part-00003-e6120af0-10c2-4248-97c4-81baf4304e5c-c000.csv
# Memory usage of dataframe is 135.41 MB
# Memory usage after optimization is: 46.16 MB
# Decreased by 65.9%
# processing file ../features/part-00004-e6120af0-10c2-4248-97c4-81baf4304e5c-c000.csv
# Memory usage of dataframe is 135.42 MB
# Memory usage after optimization is: 46.16 MB
# Decreased by 65.9%
# processing file ../features/part-00005-e6120af0-10c2-4248-97c4-81baf4304e5c-c000.csv
# Memory usage of dataframe is 135.41 MB
# Memory usage after optimization is: 46.16 MB
# Decreased by 65.9%
# processing file ../features/part-00006-e6120af0-10c2-4248-97c4-81baf4304e5c-c000.csv
# Memory usage of dataframe is 135.41 MB
# Memory usage after optimization is: 46.16 MB
# Decreased by 65.9%
# processing file ../features/part-00007-e6120af0-10c2-4248-97c4-81baf4304e5c-c000.csv
# Memory usage of dataframe is 135.42 MB
# Memory usage after optimization is: 46.16 MB
# Decreased by 65.9%
# processing file ../features/part-00008-e6120af0-10c2-4248-97c4-81baf4304e5c-c000.csv
# Memory usage of dataframe is 135.42 MB
# Memory usage after optimization is: 46.16 MB
# Decreased by 65.9%
# processing file ../features/part-00009-e6120af0-10c2-4248-97c4-81baf4304e5c-c000.csv
# Memory usage of dataframe is 135.42 MB
# Memory usage after optimization is: 46.16 MB
# Decreased by 65.9%

# %%
#get sample of 10 bookingid to test
grab_data = grab_data.set_index('bookingID').loc[grab_data.sample(10)['bookingID'].tolist()].reset_index()

# %%
grab_data = process_all_data(grab_data, test_grab_evaluation=True) 
#set test_grab_evaluation to Tre
# Out:
# Generating dataframe and feature engineering.....
# generating interaction features....
# generating feature engineering using minutes in [1, 5, 10, 15, 20, 25, 30, 60] ....
# Done!

# %%
grab_data = grab_data.merge(labels, how='left', on='bookingid') #merge with the labels

# %%
test = grab_data
y_ground_truth = grab_data.label

# %%
grab_lgb_preds = get_test_result(test, y_ground_truth, model='lgb')
# Out:
# Training until validation scores don't improve for 500 rounds.
# Early stopping, best iteration is:
# [149]	training's auc: 0.793607	valid_1's auc: 0.735233
# Fold  1 AUC : 0.735233
# Training until validation scores don't improve for 500 rounds.
# Early stopping, best iteration is:
# [148]	training's auc: 0.793273	valid_1's auc: 0.732797
# Fold  2 AUC : 0.732797
# Training until validation scores don't improve for 500 rounds.
# Early stopping, best iteration is:
# [118]	training's auc: 0.786265	valid_1's auc: 0.730245
# Fold  3 AUC : 0.730245
# Training until validation scores don't improve for 500 rounds.
# Early stopping, best iteration is:
# [190]	training's auc: 0.808311	valid_1's auc: 0.728908
# Fold  4 AUC : 0.728908
# Training until validation scores don't improve for 500 rounds.
# Early stopping, best iteration is:
# [93]	training's auc: 0.773113	valid_1's auc: 0.743349
# Fold  5 AUC : 0.743349
# Full AUC score 0.733629
# lightgbm test set AUC: 0.8571428571428571

# %%
grab_xgb_preds = get_test_result(test, y_ground_truth, model='xgb')
# Out:
# [0]	train-auc:0.640602	eval-auc:0.63879
# Multiple eval metrics have been passed: 'eval-auc' will be used for early stopping.
#
# Will train until eval-auc hasn't improved in 100 rounds.
# [100]	train-auc:0.756598	eval-auc:0.739187
# [200]	train-auc:0.778555	eval-auc:0.742302
# [300]	train-auc:0.79773	eval-auc:0.744532
# [400]	train-auc:0.812995	eval-auc:0.745301
# Stopping. Best iteration:
# [396]	train-auc:0.812327	eval-auc:0.745416
#
# Fold  1 AUC : 0.745416
# [0]	train-auc:0.640799	eval-auc:0.636976
# Multiple eval metrics have been passed: 'eval-auc' will be used for early stopping.
#
# Will train until eval-auc hasn't improved in 100 rounds.
# [100]	train-auc:0.755552	eval-auc:0.739603
# [200]	train-auc:0.776864	eval-auc:0.743066
# [300]	train-auc:0.795824	eval-auc:0.744526
# [400]	train-auc:0.812234	eval-auc:0.745672
# [500]	train-auc:0.825632	eval-auc:0.745764
# [600]	train-auc:0.838313	eval-auc:0.74604
# Stopping. Best iteration:
# [579]	train-auc:0.835646	eval-auc:0.746438
#
# Fold  2 AUC : 0.746438
# [0]	train-auc:0.679825	eval-auc:0.664391
# Multiple eval metrics have been passed: 'eval-auc' will be used for early stopping.
#
# Will train until eval-auc hasn't improved in 100 rounds.
# [100]	train-auc:0.760784	eval-auc:0.722087
# [200]	train-auc:0.781317	eval-auc:0.726333
# [300]	train-auc:0.797715	eval-auc:0.72868
# [400]	train-auc:0.812183	eval-auc:0.731437
# [500]	train-auc:0.825951	eval-auc:0.73115
# Stopping. Best iteration:
# [424]	train-auc:0.815357	eval-auc:0.731924
#
# Fold  3 AUC : 0.731924
# [0]	train-auc:0.674614	eval-auc:0.663223
# Multiple eval metrics have been passed: 'eval-auc' will be used for early stopping.
#
# Will train until eval-auc hasn't improved in 100 rounds.
# [100]	train-auc:0.75686	eval-auc:0.734449
# [200]	train-auc:0.777717	eval-auc:0.737111
# [300]	train-auc:0.79716	eval-auc:0.741218
# [400]	train-auc:0.812991	eval-auc:0.741257
# [500]	train-auc:0.827264	eval-auc:0.741351
# Stopping. Best iteration:
# [476]	train-auc:0.824412	eval-auc:0.742016
#
# Fold  4 AUC : 0.742016
# Full AUC score 0.741271
# xgboost test set AUC: 0.9047619047619049

# %%
print(f'mean combined predictions for evaluation files of single xgb and lgb models \
{roc_auc_score(y_ground_truth, ((grab_lgb_preds + grab_xgb_preds) / 2))}')
# Out:
# mean combined predictions for evaluation files of single xgb and lgb models 0.8571428571428572
